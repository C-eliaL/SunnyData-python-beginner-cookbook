# %% [markdown]
# # Chapter 3: 輸入輸出與格式化 - 自我測驗
#
# 本測驗包含 **28 題**，用於檢驗您對本章內容的掌握程度。
#
# ## 測驗資訊
# - **題型**：選擇題 15 題 + 是非題 5 題 + 輸出預測 5 題 + 填空題 3 題
# - **總分**：100 分
# - **及格**：70 分
# - **建議時間**：20 分鐘
#
# ---

# %% [markdown]
# ## Part I: 選擇題（60 分）
#
# 每題 4 分，共 15 題。
#
# ---

# %% [markdown]
# ### 第 1 題
#
# `input()` 函式的回傳值型態永遠是？
#
# (A) int
# (B) float
# (C) str
# (D) 視輸入內容而定
#
# **答案**：<details><summary>點擊查看</summary>(C) str<br><br>**解析**：input() 永遠回傳字串型態，即使使用者輸入數字，也需要手動轉換為 int 或 float。</details>
#
# ---

# %% [markdown]
# ### 第 2 題
#
# 以下何者可以讓 `print()` 不換行？
#
# (A) `print(..., sep="")`
# (B) `print(..., end="")`
# (C) `print(..., newline=False)`
# (D) `print(..., nl=False)`
#
# **答案**：<details><summary>點擊查看</summary>(B) print(..., end="")<br><br>**解析**：end 參數控制 print() 結尾字元，預設是換行符 "\n"。設定為 "" 可以不換行。</details>
#
# ---

# %% [markdown]
# ### 第 3 題
#
# `f"{3.14159:.2f}"` 的輸出結果是？
#
# (A) 3.14159
# (B) 3.14
# (C) 3.1
# (D) 3
#
# **答案**：<details><summary>點擊查看</summary>(B) 3.14<br><br>**解析**：:.2f 表示格式化為浮點數，保留 2 位小數。</details>
#
# ---

# %% [markdown]
# ### 第 4 題
#
# `print("A", "B", "C", sep="-")` 的輸出是？
#
# (A) ABC
# (B) A-B-C
# (C) A B C
# (D) A\nB\nC
#
# **答案**：<details><summary>點擊查看</summary>(B) A-B-C<br><br>**解析**：sep 參數定義多個值之間的分隔符，這裡設定為 "-"。</details>
#
# ---

# %% [markdown]
# ### 第 5 題
#
# `f"{42:05d}"` 的輸出是？
#
# (A) 42
# (B) 00042
# (C) 42000
# (D) 錯誤
#
# **答案**：<details><summary>點擊查看</summary>(B) 00042<br><br>**解析**：05d 表示整數寬度 5，不足部分補 0。</details>
#
# ---

# %% [markdown]
# ### 第 6 題
#
# 以下哪個程式碼會產生錯誤？
#
# (A) `age = int(input("年齡："))`
# (B) `name = str(input("姓名："))`
# (C) `height = float(input("身高："))`
# (D) 以上皆不會錯誤
#
# **答案**：<details><summary>點擊查看</summary>(D) 以上皆不會錯誤<br><br>**解析**：所有選項語法都正確，(B) 雖然多餘（input() 本就回傳 str），但不會報錯。</details>
#
# ---

# %% [markdown]
# ### 第 7 題
#
# `f"{1234567.89:,.2f}"` 的輸出是？
#
# (A) 1234567.89
# (B) 1,234,567.89
# (C) 1234567.9
# (D) 1,234,567.890
#
# **答案**：<details><summary>點擊查看</summary>(B) 1,234,567.89<br><br>**解析**：, 表示千分位分隔符，.2f 表示保留 2 位小數。</details>
#
# ---

# %% [markdown]
# ### 第 8 題
#
# `f"{0.856:.1%}"` 的輸出是？
#
# (A) 0.9%
# (B) 85.6%
# (C) 0.856%
# (D) 86%
#
# **答案**：<details><summary>點擊查看</summary>(B) 85.6%<br><br>**解析**：.1% 將小數轉為百分比並保留 1 位小數（0.856 * 100 = 85.6）。</details>
#
# ---

# %% [markdown]
# ### 第 9 題
#
# `f"{'Alice':<10}"` 的輸出長度是？
#
# (A) 5
# (B) 10
# (C) 15
# (D) 不固定
#
# **答案**：<details><summary>點擊查看</summary>(B) 10<br><br>**解析**：<10 表示左對齊且寬度為 10，不足部分用空格填充（"Alice     "）。</details>
#
# ---

# %% [markdown]
# ### 第 10 題
#
# `print()` 的預設分隔符是？
#
# (A) ""（空字串）
# (B) " "（空格）
# (C) ","（逗號）
# (D) "\t"（Tab）
#
# **答案**：<details><summary>點擊查看</summary>(B) " "（空格）<br><br>**解析**：print() 預設用空格分隔多個參數。</details>
#
# ---

# %% [markdown]
# ### 第 11 題
#
# 若要讓使用者輸入整數並立即相加，以下何者正確？
#
# (A) `a + b = int(input()) + int(input())`
# (B) `result = input() + input()`
# (C) `result = int(input()) + int(input())`
# (D) `result = int(input() + input())`
#
# **答案**：<details><summary>點擊查看</summary>(C) result = int(input()) + int(input())<br><br>**解析**：必須分別將兩個 input() 轉為 int 再相加。(D) 會先串接字串再轉換。</details>
#
# ---

# %% [markdown]
# ### 第 12 題
#
# `f"{42:>10}"` 代表？
#
# (A) 左對齊，寬度 10
# (B) 右對齊，寬度 10
# (C) 置中對齊，寬度 10
# (D) 補零，寬度 10
#
# **答案**：<details><summary>點擊查看</summary>(B) 右對齊，寬度 10<br><br>**解析**：> 表示右對齊，輸出為 "        42"（前面 8 個空格）。</details>
#
# ---

# %% [markdown]
# ### 第 13 題
#
# 以下何者**不是**有效的 f-string 語法？
#
# (A) `f"{name}"`
# (B) `f"{age + 1}"`
# (C) `f"{name.upper()}"`
# (D) `f"{if age > 18: 'adult'}"`
#
# **答案**：<details><summary>點擊查看</summary>(D) f"{if age > 18: 'adult'}"<br><br>**解析**：f-string 中不能直接使用 if 語句，應使用條件表達式：f"{age > 18 if 'adult' else 'minor'}"</details>
#
# ---

# %% [markdown]
# ### 第 14 題
#
# `f"{3.14:.0f}"` 的輸出是？
#
# (A) 3.14
# (B) 3.0
# (C) 3
# (D) 錯誤
#
# **答案**：<details><summary>點擊查看</summary>(C) 3<br><br>**解析**：.0f 表示保留 0 位小數，會四捨五入並顯示整數。</details>
#
# ---

# %% [markdown]
# ### 第 15 題
#
# 要置中對齊字串 "Hi" 在寬度 10 的空間，應使用？
#
# (A) `f"{'Hi':>10}"`
# (B) `f"{'Hi':<10}"`
# (C) `f"{'Hi':^10}"`
# (D) `f"{'Hi':=10}"`
#
# **答案**：<details><summary>點擊查看</summary>(C) f"{'Hi':^10}"<br><br>**解析**：^ 表示置中對齊，輸出為 "    Hi    "。</details>
#
# ---

# %% [markdown]
# ## Part II: 是非題（20 分）
#
# 每題 4 分，共 5 題。請判斷以下敘述是否正確。
#
# ---

# %% [markdown]
# ### 第 16 題
#
# `input("請輸入：")` 中的字串參數是選用的，可以省略。
#
# **答案**：<details><summary>點擊查看</summary>✓ 正確<br><br>**解析**：提示訊息是選用參數，`input()` 不帶參數也能執行。</details>
#
# ---

# %% [markdown]
# ### 第 17 題
#
# `print()` 最多只能接受 3 個參數。
#
# **答案**：<details><summary>點擊查看</summary>✗ 錯誤<br><br>**解析**：print() 可接受任意數量的參數。</details>
#
# ---

# %% [markdown]
# ### 第 18 題
#
# f-string 是 Python 3.6 以上版本才支援的功能。
#
# **答案**：<details><summary>點擊查看</summary>✓ 正確<br><br>**解析**：f-string 是 Python 3.6 引入的新特性。</details>
#
# ---

# %% [markdown]
# ### 第 19 題
#
# `int(input())` 無法處理使用者輸入小數，會產生 ValueError。
#
# **答案**：<details><summary>點擊查看</summary>✓ 正確<br><br>**解析**：int() 無法轉換帶小數點的字串，應使用 float()。</details>
#
# ---

# %% [markdown]
# ### 第 20 題
#
# `print("a", "b", sep="", end="")` 會輸出 "ab" 且不換行。
#
# **答案**：<details><summary>點擊查看</summary>✓ 正確<br><br>**解析**：sep="" 移除分隔符，end="" 移除換行符。</details>
#
# ---

# %% [markdown]
# ## Part III: 程式輸出預測（15 分）
#
# 每題 3 分，共 5 題。請預測以下程式碼的輸出。
#
# ---

# %% [markdown]
# ### 第 21 題
#
# ```python
# print("1", "2", "3", sep="*", end="!\n")
# ```
#
# **答案**：<details><summary>點擊查看</summary>1*2*3!<br><br>**解析**：sep="*" 用星號分隔，end="!\n" 結尾加驚嘆號。</details>
#
# ---

# %% [markdown]
# ### 第 22 題
#
# ```python
# pi = 3.14159
# print(f"{pi:.3f}")
# ```
#
# **答案**：<details><summary>點擊查看</summary>3.142<br><br>**解析**：.3f 保留 3 位小數，會四捨五入。</details>
#
# ---

# %% [markdown]
# ### 第 23 題
#
# ```python
# name = "Bob"
# age = 25
# print(f"{name:>10} is {age:<5} years old")
# ```
#
# **答案**：<details><summary>點擊查看</summary>       Bob is 25    years old<br><br>**解析**：name 右對齊寬度10，age 左對齊寬度5。</details>
#
# ---

# %% [markdown]
# ### 第 24 題
#
# ```python
# num = 7
# print(f"{num:04d}")
# ```
#
# **答案**：<details><summary>點擊查看</summary>0007<br><br>**解析**：04d 表示寬度 4，不足補零。</details>
#
# ---

# %% [markdown]
# ### 第 25 題
#
# ```python
# ratio = 0.75
# print(f"{ratio:.0%}")
# ```
#
# **答案**：<details><summary>點擊查看</summary>75%<br><br>**解析**：.0% 轉為百分比且不保留小數。</details>
#
# ---

# %% [markdown]
# ## Part IV: 程式填空（5 分）
#
# 每題 5 分，共 3 題。
#
# ---

# %% [markdown]
# ### 第 26 題
#
# 完成以下程式，讓使用者輸入兩個整數並計算總和。
#
# ```python
# num1 = _____(input("第一個數字："))
# num2 = _____(input("第二個數字："))
# result = num1 + num2
# print(f"總和：{result}")
# ```
#
# **答案**：<details><summary>點擊查看</summary>int<br><br>**解析**：需要用 int() 將字串轉為整數。</details>
#
# ---

# %% [markdown]
# ### 第 27 題
#
# 完成格式化字串，輸出浮點數 pi 保留 2 位小數。
#
# ```python
# pi = 3.14159265
# print(f"{pi_____}")
# # 預期輸出：3.14
# ```
#
# **答案**：<details><summary>點擊查看</summary>:.2f<br><br>**解析**：:.2f 格式化為浮點數，保留 2 位小數。</details>
#
# ---

# %% [markdown]
# ### 第 28 題
#
# 完成 print() 使其輸出不換行。
#
# ```python
# print("第一行", _____="")
# print("第二行")
# # 預期輸出：第一行第二行
# ```
#
# **答案**：<details><summary>點擊查看</summary>end<br><br>**解析**：end="" 讓 print() 不換行。</details>
#
# ---

# %% [markdown]
# ## 測驗結束
#
# ### 評分標準
# - Part I 選擇題：15 題 × 4 分 = 60 分
# - Part II 是非題：5 題 × 4 分 = 20 分
# - Part III 輸出預測：5 題 × 3 分 = 15 分
# - Part IV 填空題：3 題 × 5 分 = 15 分
# - **總分：110 分（額外 10 分）**
# - **及格：70 分**
#
# ### 學習建議
# - **90 分以上**：優秀！可進入 Milestone 1
# - **70-89 分**：良好，建議複習格式化語法
# - **60-69 分**：及格，需加強練習 f-string
# - **60 分以下**：建議重新學習本章，完成所有練習
#
# ### 下一步
# - 完成 **Milestone 1: 簡易計算機**
# - 學習 **Chapter 4: 條件判斷**
#
# **恭喜完成 Ch03 測驗！** 🎉
