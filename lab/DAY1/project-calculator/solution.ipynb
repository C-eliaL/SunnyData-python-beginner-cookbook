# %% [markdown]
# # 簡易計算機 | Solution Notebook
#
# 以下提供 Step A→C (含 Bonus) 的參考解答。
#
# ## 📝 使用說明
#
# 此解答對應 `starter-code.ipynb` 中的 **📝 實作區（TODO 區塊）**：
# - **Step A 解答** → 對應 starter-code 的 Cell 2 (TODO 區塊)
# - **Step B 解答** → 對應 starter-code 的 Cell 5 (TODO 區塊)
# - **Step C 解答** → 對應 starter-code 的 Cell 8 (TODO 區塊)
# - **Bonus 解答** → 對應 starter-code 的 Cell 10 (TODO 區塊)
#
# **注意**：此解答不包含測試區的內容，測試區的程式碼在 `starter-code.ipynb` 中已提供。

# %% [markdown]
# ## Step A：完成輸入功能

# %%
# ============================================
# 📝 Step A 實作區解答
# 對應 starter-code.ipynb 的 Cell 2 (TODO 區塊)
# ============================================
# 取得使用者輸入
num1 = float(input("請輸入第一個數字: "))
num2 = float(input("請輸入第二個數字: "))

# %% [markdown]
# ## Step B：實作計算邏輯

# %%
# ============================================
# 📝 Step B 實作區解答
# 對應 starter-code.ipynb 的 Cell 5 (TODO 區塊)
# ============================================
# 執行加法運算
result = num1 + num2

# %% [markdown]
# ## Step C：格式化輸出

# %%
# ============================================
# 📝 Step C 實作區解答
# 對應 starter-code.ipynb 的 Cell 8 (TODO 區塊)
# ============================================
# 整合所有功能，完成最終輸出
print("=== 歡迎使用簡易加法計算機 ===")
print()

# 取得輸入
num1 = float(input("請輸入第一個數字: "))
num2 = float(input("請輸入第二個數字: "))

# 執行加法運算
result = num1 + num2

# 顯示結果
print(f"\n計算結果：{num1} + {num2} = {result}")
print("\n感謝使用計算機！")

# %% [markdown]
# ## Bonus：進階思考與挑戰（示例）

# %%
# ============================================
# 📝 Bonus 實作區解答
# 對應 starter-code.ipynb 的 Cell 10 (TODO 區塊)
# ============================================
# 挑戰 1：計算三個數字的總和
print("=== 挑戰 1：三個數字相加 ===")
num1 = float(input("請輸入第一個數字: "))
num2 = float(input("請輸入第二個數字: "))
num3 = float(input("請輸入第三個數字: "))

result = num1 + num2 + num3
print(f"\n計算結果：{num1} + {num2} + {num3} = {result}")

# 挑戰 2：美化輸出
print("\n" + "="*40)
print("=== 挑戰 2：美化輸出 ===")
print("="*40)

num1 = float(input("請輸入第一個數字: "))
num2 = float(input("請輸入第二個數字: "))
result = num1 + num2

print("\n" + "="*40)
print(f"📊 計算結果：{num1} + {num2} = {result}")
print("="*40)
print("✅ 計算完成！")

# 思考題：如果要支援減法、乘法、除法，需要什麼新的知識？
print("\n" + "="*40)
print("💡 思考題：")
print("如果要支援減法、乘法、除法，需要什麼新的知識？")
print("提示：需要學習 Ch04 條件判斷（if/elif/else）")
print("才能根據使用者的選擇執行不同的運算。")
print("="*40)
