# %% [markdown]
# # 簡易計算機 | Starter Notebook
#
# 依序完成 Step A→C，確保每一步都能執行後再前進。
#
# ## 📝 使用說明
#
# 每個步驟包含兩個區塊：
# 1. **📝 實作區（TODO 區塊）**：在這裡填入你的程式碼
# 2. **✅ 測試區**：執行後驗證你的程式碼是否正確
#
# ### ⚠️ 重要：不需要複製程式碼！
#
# **正確流程**：
# 1. 在「📝 實作區」填入程式碼
# 2. **執行「📝 實作區」這個 cell**（按 Shift+Enter）
# 3. **執行「✅ 測試區」這個 cell**（按 Shift+Enter）
# 4. 測試區會自動讀取實作區中定義的變數，不需要複製程式碼！
#
# **為什麼不需要複製？**
# - Jupyter Notebook 中，所有 cell 共享同一個執行環境
# - 在實作區定義的變數（如 `num1`, `num2`），測試區可以直接使用

# %% [markdown]
# ## Step A：完成輸入功能
#
# - 功能：使用 `input()` 取得使用者輸入並正確轉換型態
# - 提示：使用 `float()` 轉換數字，可同時支援整數和小數
# - 需要取得：第一個數字、第二個數字

# %%
# ============================================
# 📝 實作區：請在這裡填入你的程式碼
# ============================================
# TODO: 取得使用者輸入
# 建議步驟：
# 1. num1 = float(input("請輸入第一個數字: "))
# 2. num2 = float(input("請輸入第二個數字: "))
# 3. print 確認輸入是否正確

# %%
# ============================================
# ✅ 測試區：執行此 cell 驗證你的程式碼
# ============================================
# 💡 說明：此測試區會自動讀取上方實作區定義的變數
#         不需要複製程式碼，直接執行即可！
# ============================================
# 確認輸入正確取得
try:
    print("=== 輸入測試 ===")
    print(f"第一個數字：{num1} (型態: {type(num1).__name__})")
    print(f"第二個數字：{num2} (型態: {type(num2).__name__})")
    print("✅ 通過 Step A 測試")
except NameError:
    print("⚠️ 尚未定義變數 num1, num2")
    print("💡 提示：請先在上方的「📝 實作區」填入程式碼並執行")

# %% [markdown]
# ## Step B：實作計算邏輯
#
# - 執行兩個數字的加法運算
# - 使用加法運算子 `+` 計算結果
# - 將結果儲存在變數中

# %%
# ============================================
# 📝 實作區：請在這裡填入你的程式碼
# ============================================
# TODO: 執行加法運算
# 建議步驟：
# 1. 使用加法運算子 + 計算結果
# 2. 將結果儲存在 result 變數中
# 範例：
# result = num1 + num2

# %%
# ============================================
# ✅ 測試區：執行此 cell 驗證你的程式碼
# ============================================
# 💡 說明：此測試區會自動讀取上方實作區定義的變數
#         不需要複製程式碼，直接執行即可！
# ============================================
# 驗證計算結果
# 測試案例：10 + 5 = 15, 3.5 + 2.5 = 6.0, -5 + 3 = -2
try:
    print("=== 計算測試 ===")
    print(f"計算結果：{result}")
    # 可以手動驗證結果是否正確
    print("✅ 通過 Step B 測試（請確認結果正確）")
except NameError:
    print("⚠️ 尚未定義 result 變數")
    print("💡 提示：請先在上方的「📝 實作區」填入程式碼並執行")

# %% [markdown]
# ## Step C：格式化輸出
#
# - 使用 f-string 以易讀格式顯示計算結果
# - 格式：`數字1 運算符號 數字2 = 結果`
# - 加入適當的提示訊息和歡迎文字

# %%
# ============================================
# 📝 實作區：請在這裡填入你的程式碼
# ============================================
# TODO: 整合所有功能，完成最終輸出
# 小提示：可使用 f-string 排版
# 範例：
# print("=== 歡迎使用簡易加法計算機 ===")
# print(f"計算結果：{num1} + {num2} = {result}")
# print("感謝使用計算機！")
# 
# 💡 提示：這個步驟不需要測試區，直接執行程式即可看到完整效果

# %% [markdown]
# ## Bonus：進階思考與挑戰
#
# - 計算三個數字的總和（例如：10 + 5 + 3 = 18）
# - 美化輸出：使用分隔線、表情符號等
# - 思考題：如果要支援減法、乘法、除法，需要什麼新的知識？
# - 預告：在未來的章節（Ch04 條件判斷）中，我們會學習如何根據使用者的選擇執行不同的運算

# %%
# 在此區嘗試進階功能，例如：
# - 計算三個數字：num1 + num2 + num3
# - 美化輸出：使用分隔線 print("=" * 30)
# - 使用表情符號：print("✅ 計算完成！")
# - 思考：如果要支援減法，需要什麼新知識？（提示：條件判斷）
