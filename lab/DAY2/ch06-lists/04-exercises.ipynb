# %% [markdown]
# # Chapter 6: 序列資料：列表 | Sequential Data: Lists
#
# ## ✍️ 課後習題 | Exercises
#
# 本檔案包含 12 道課後習題：
# - **基礎題**（1-4）：基本列表操作
# - **中級題**（5-8）：列表方法應用
# - **挑戰題**（9-12）：綜合應用
#
# **預計完成時間**：90-120 分鐘
#
# ---

# %% [markdown]
# ## 📘 基礎題（1-4）
#
# ### 習題 1：建立星期列表 ⭐
#
# **要求**：
# 建立一個包含七天的列表：["星期一", "星期二", ..., "星期日"]
#
# 輸出：
# 1. 第一天和最後一天
# 2. 工作日（前 5 天）
# 3. 週末（後 2 天）

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 2：數字列表操作 ⭐
#
# **要求**：
# 給定列表 `numbers = [5, 10, 15, 20, 25, 30]`
#
# 計算：
# 1. 列表中所有數字的總和
# 2. 列表中所有數字的平均值
# 3. 最大值與最小值的差

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 3：列表元素檢查 ⭐
#
# **要求**：
# 給定列表 `colors = ["紅", "黃", "藍", "綠", "紫"]`
#
# 檢查：
# 1. "藍" 是否在列表中
# 2. "橙" 是否在列表中
# 3. 列表的長度是否大於 3

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 4：修改列表元素 ⭐
#
# **要求**：
# 給定列表 `prices = [100, 200, 300, 400, 500]`
#
# 操作：
# 1. 將第一個價格改為 150
# 2. 將最後一個價格改為 550
# 3. 輸出修改後的列表

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ## 📙 中級題（5-8）
#
# ### 習題 5：購物清單管理 ⭐⭐
#
# **要求**：
# 從空列表開始，執行以下操作：
# 1. 加入 "麵包", "牛奶", "雞蛋"
# 2. 在開頭插入 "水果"
# 3. 移除 "牛奶"
# 4. 加入 "起司" 和 "果汁"
# 5. 輸出最終清單與總項目數

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 6：成績排名 ⭐⭐
#
# **要求**：
# 給定成績列表 `scores = [88, 92, 75, 95, 82, 90]`
#
# 操作：
# 1. 建立一個新列表，包含排序後的成績（由高到低）
# 2. 找出第一名的成績
# 3. 找出最後一名的成績
# 4. 計算前三名的平均分
#
# **注意**：不要修改原始列表

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 7：數字過濾 ⭐⭐
#
# **要求**：
# 給定列表 `numbers = [12, 7, 23, 8, 45, 16, 31, 19, 5]`
#
# 操作：
# 1. 建立一個新列表，只包含大於 10 的數字
# 2. 建立一個新列表，只包含偶數
# 3. 計算所有奇數的總和

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 8：列表合併與去重 ⭐⭐
#
# **要求**：
# 給定兩個列表：
# - `list1 = [1, 2, 3, 4, 5]`
# - `list2 = [4, 5, 6, 7, 8]`
#
# 操作：
# 1. 合併兩個列表
# 2. 找出共同元素（同時出現在兩個列表中）
# 3. 找出只在 list1 中的元素

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ## 📕 挑戰題（9-12）
#
# ### 習題 9：班級成績系統 ⭐⭐⭐
#
# **要求**：
# 建立一個簡單的成績管理系統。
#
# 給定學生姓名與成績（使用兩個平行列表）：
# - `names = ["小明", "小華", "小美", "小強", "小芳"]`
# - `scores = [85, 92, 78, 95, 88]`
#
# 輸出：
# 1. 最高分的學生姓名與分數
# 2. 最低分的學生姓名與分數
# 3. 所有及格（≥60）的學生姓名
# 4. 按成績由高到低輸出學生姓名與分數

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 10：數字序列生成 ⭐⭐⭐
#
# **要求**：
# 使用列表建立以下數字序列（不使用 range）：
#
# 1. 1 到 20 的所有偶數：[2, 4, 6, ..., 20]
# 2. 1 到 10 的平方數：[1, 4, 9, 16, ..., 100]
# 3. 10 到 1 的倒數序列：[10, 9, 8, ..., 1]

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 11：溫度轉換清單 ⭐⭐⭐
#
# **要求**：
# 給定一週的攝氏溫度：`celsius_temps = [25, 28, 22, 30, 27, 26, 24]`
#
# 操作：
# 1. 建立對應的華氏溫度列表（公式：F = C × 9/5 + 32）
# 2. 找出最熱的一天（華氏溫度）
# 3. 找出最冷的一天（攝氏溫度）
# 4. 計算平均溫度（攝氏）
# 5. 統計高於平均溫度的天數

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---
#
# ### 習題 12：完整的待辦清單系統 ⭐⭐⭐
#
# **要求**：
# 建立一個待辦清單系統，實作以下功能：
#
# 1. **新增任務**：加入 5 個任務到清單
# 2. **顯示清單**：用編號顯示所有任務（1. 任務一\n2. 任務二...）
# 3. **完成任務**：移除第 3 個任務（模擬完成）
# 4. **插入緊急任務**：在開頭插入一個緊急任務
# 5. **統計**：顯示剩餘任務數量
# 6. **清空**：清空所有任務
#
# **提示**：可以自己設計任務內容

# %%
# 在此撰寫程式碼

# %% [markdown]
# ---## 🎯 習題總結### 涵蓋的知識點| 題號 | 主題 | 難度 | 重點技能 ||:----:|:-----|:----:|:--------|| 1 | 列表建立與切片 | ⭐ | 基本操作 || 2 | 內建函數應用 | ⭐ | sum, max, min || 3 | 成員檢查 | ⭐ | in 運算子 || 4 | 元素修改 | ⭐ | 索引賦值 || 5 | 列表管理 | ⭐⭐ | append, insert, remove || 6 | 排序與統計 | ⭐⭐ | sorted(), 切片 || 7 | 條件過濾 | ⭐⭐ | for 迴圈, if || 8 | 列表運算 | ⭐⭐ | 合併, 交集, 差集 || 9 | 平行列表 | ⭐⭐⭐ | zip, enumerate, index || 10 | 序列生成 | ⭐⭐⭐ | 迴圈建立列表 || 11 | 資料轉換 | ⭐⭐⭐ | 列表推導, 統計分析 || 12 | 系統整合 | ⭐⭐⭐ | 綜合應用 |### 能力檢核完成習題後，確認你能夠：**基礎能力**- [ ] 建立與存取列表- [ ] 使用切片取得子列表- [ ] 修改列表元素- [ ] 使用 in 檢查成員**進階能力**- [ ] 熟練使用列表方法（append, insert, remove, pop, sort）- [ ] 使用 for 迴圈遍歷與處理列表- [ ] 進行列表過濾與轉換- [ ] 處理多個列表的運算**應用能力**- [ ] 解決實際問題（成績管理、待辦清單）- [ ] 處理平行列表（對應關係）- [ ] 進行資料統計與分析- [ ] 設計完整的列表操作流程---## 📚 下一步完成詳解範例後，繼續進行 `03-practice.ipynb` 和 `04-exercises.ipynb`。
