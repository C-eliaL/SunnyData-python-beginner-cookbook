# %% [markdown]
# # 理財小幫手 | Starter Notebook
#
# 依序完成 Step A→C，確保每一步都能執行後再前進。

# %% [markdown]
# ## Step A：建立 `calculate_savings`
#
# - 功能：回傳收入與總支出差額
# - 提示：函式只負責計算，不做輸出
# - 先用假資料測試 (例如 income=40000, expense=32000)

# %%
# TODO: 定義 calculate_savings(income, total_expense)
# 1. 使用具描述性的參數名稱
# 2. 回傳收入減總支出
# 3. 保持函式純粹，不要在這裡 print

# %%
# 測試區：執行後應印出 8000
# 可以調整數值檢查結果
try:
    result = calculate_savings(40000, 32000)
    print(f"計算結果：{result}")
    assert result == 8000
    print("✅ 通過 Step A 測試")
except NameError:
    print("⚠️ 尚未定義 calculate_savings")

# %% [markdown]
# ## Step B：輸入收入與三項支出
#
# - 依序詢問：收入、房租、飲食、娛樂
# - 使用 `int(input(...))` 並清楚標示金額單位 (元)
# - 將三項支出加總為 `total_expense`
# - 請先以真實或假想數字測試

# %%
# TODO: 取得使用者輸入並計算 total_expense
# 建議步驟：
# 1. income = int(input("請輸入本月收入 (元)："))
# 2. rent_expense = ...
# 3. food_expense = ...
# 4. fun_expense = ...
# 5. total_expense = rent_expense + food_expense + fun_expense
# 6. print 確認輸入是否正確

# %% [markdown]
# ## Step C：判斷並給出建議
#
# - 呼叫 `calculate_savings(income, total_expense)`
# - 依照結果：
#   - > 0：太棒了！繼續保持！
#   - == 0：收支平衡，加油！
#   - < 0：要小心，支出超標囉！
# - 顯示摘要報告：收入、總支出、儲蓄
# - 以早期返回或清楚的 `if/elif/else` 提升可讀性

# %%
# TODO: 整合輸入與函式，完成最終輸出
# 小提示：可使用 f-string 排版
# 範例：
# print("=== 本月收支報告 ===")
# print(f"收入：{income} 元")
# ...

# %% [markdown]
# ## Bonus：輸入驗證 / 建議升級
#
# - 使用 `try-except` 防止非數字輸入
# - 防堵負數：若小於 0，要求重新輸入
# - 依儲蓄幅度提供額外建議 (例如設定 20% 自動轉帳)
# - 自訂表格排版或輸出到檔案

# %%
# 在此區嘗試進階功能，例如：
# - 定義 get_positive_int(prompt)
# - 儲蓄建議函式
# - 多月資料比較
