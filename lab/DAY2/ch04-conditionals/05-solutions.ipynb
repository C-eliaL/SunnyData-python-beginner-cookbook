# %% [markdown]
# # Chapter 4: 條件判斷 - 習題解答
#
# ## 📖 完整解答 | Complete Solutions
#
# ---
#
# ## 💡 重要說明
#
# 本章節的 `04-exercises.ipynb` 尚未補充完整內容。本解答檔案提供基於 `01-lecture.ipynb` 範例的**延伸練習解答**，作為學習參考。
#
# **建議學習流程**：
# 1. ✅ 完成 `01-lecture.ipynb` 所有範例
# 2. ✅ 完成 `02-worked-examples.ipynb` 詳解案例
# 3. ✅ 完成 `03-practice.ipynb` 課堂練習
# 4. ✅ 完成 `quiz.ipynb` 自我測驗（28 題）
# 5. ✅ 參考本檔案的延伸練習
#
# ---

# %% [markdown]
# ### 習題 1：基本 if 語句 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ## Part I: 基礎題（6 題）🟢
#
# ### 習題 1：基本 if 語句 🟢
#
# **題目**：
# 寫一個程式，判斷學生是否及格：
# - 輸入：分數（例如：`score = 75`）
# - 條件：分數 >= 60 為及格
# - 輸出：如果及格，印出「恭喜！你及格了！」
#
# **要求**：
# - 使用簡單的 if 語句
# - 測試不同分數值（60, 59, 85）

# %%
# 解答
age = 25

if age < 0:
    category = "輸入錯誤"
elif age <= 12:
    category = "兒童"
elif age <= 19:
    category = "青少年"
elif age <= 64:
    category = "成年人"
else:
    category = "長者"

print(f"年齡：{age} 歲，分類：{category}")

# %% [markdown]
# **常見錯誤**：
# - ❌ 條件順序錯誤（例如先判斷 `age <= 64`）
# - ❌ 忘記處理負數
# - ❌ 邊界值判斷錯誤（12, 19, 64）
#
# ---

# %% [markdown]
# ### 習題 2：if-else 二選一 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 2：if-else 二選一 🟢
#
# **題目**：
# 設計一個年齡判斷程式：
# - 輸入：年齡（例如：`age = 17`）
# - 判斷：是否已成年（18 歲以上）
# - 輸出：
#   - 已成年：「你已經成年，可以投票了！」
#   - 未成年：「你還未成年，需要等到 18 歲才能投票。」
#
# **要求**：
# - 使用 if-else 語句
# - 測試邊界值（17, 18, 20）

# %%
# 解答
score = 85

if score < 0 or score > 100:
    grade = "輸入錯誤"
    message = "分數必須在 0-100 之間"
elif score >= 90:
    grade = "A"
    message = "優秀"
elif score >= 80:
    grade = "B"
    message = "良好"
elif score >= 70:
    grade = "C"
    message = "中等"
elif score >= 60:
    grade = "D"
    message = "及格"
else:
    grade = "F"
    message = "不及格"

print(f"分數：{score}，等級：{grade}，評語：{message}")

# %% [markdown]
# **重點提示**：
# - 先檢查輸入範圍（0-100）
# - 從大到小判斷，確保邏輯正確
# - `score >= 80` 隱含「且 < 90」（因為已排除 >= 90）
#
# ---

# %% [markdown]
# ### 習題 3：比較運算子練習 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 3：比較運算子練習 🟢
#
# **題目**：
# 比較兩個數字的大小關係：
# - 輸入：兩個數字（例如：`a = 25`, `b = 30`）
# - 輸出：所有可能的比較結果
#
# **要求**：
# 使用 6 種比較運算子，輸出格式如下：
# ```
# 25 > 30: False
# 25 < 30: True
# 25 >= 30: False
# 25 <= 30: True
# 25 == 30: False
# 25 != 30: True
# ```

# %%
# 解答方法 1：傳統 if-else
num = 7

if num % 2 == 0:
    result = "偶數"
else:
    result = "奇數"

print(f"{num} 是{result}")

# %%
# 解答方法 2：三元運算子（更簡潔）
num = 7
result = "偶數" if num % 2 == 0 else "奇數"
print(f"{num} 是{result}")

# %% [markdown]
# **延伸思考**：
# - `num % 2 == 1` vs `num % 2 != 0`：都可以判斷奇數
# - 負數也適用（-7 % 2 = 1）
#
# ---

# %% [markdown]
# ### 習題 4：邏輯運算子基礎 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 4：邏輯運算子基礎 🟢
#
# **題目**：
# 設計一個簡單的密碼檢查程式：
# - 給定條件：
#   - `password_correct = True`（密碼正確）
#   - `account_locked = False`（帳戶未鎖定）
# - 判斷：只有當密碼正確**且**帳戶未鎖定時才能登入
# - 輸出：
#   - 可以登入：「登入成功！」
#   - 不能登入：「登入失敗！」
#
# **要求**：
# 使用 `and` 邏輯運算子

# %%
# 解答
a, b, c = 15, 28, 22

if a >= b and a >= c:
    maximum = a
elif b >= a and b >= c:
    maximum = b
else:
    maximum = c

print(f"三個數 {a}, {b}, {c} 的最大值是 {maximum}")

# %% [markdown]
# **其他解法**（巢狀條件）：
# ```python
# if a >= b:
#     if a >= c:
#         maximum = a
#     else:
#         maximum = c
# else:
#     if b >= c:
#         maximum = b
#     else:
#         maximum = c
# ```
#
# ---

# %% [markdown]
# ### 習題 5：溫度判斷 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 5：溫度判斷 🟢
#
# **題目**：
# 根據溫度決定穿衣建議：
# - 輸入：溫度（例如：`temperature = 15`）
# - 判斷標準：
#   - 溫度 < 10°C：「很冷，建議穿厚外套」
#   - 溫度 >= 10°C：「不會太冷，穿一般衣服即可」
#
# **要求**：
# - 使用 if-else 語句
# - 測試不同溫度（5, 10, 15）

# %%
# 解答
year = 2024

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    result = "閏年"
else:
    result = "平年"

print(f"{year} 年是{result}")

# 測試案例
test_years = [2000, 1900, 2024, 2023]
for y in test_years:
    is_leap = (y % 4 == 0 and y % 100 != 0) or (y % 400 == 0)
    print(f"{y}: {'閏年' if is_leap else '平年'}")

# %% [markdown]
# **測試案例驗證**：
# - 2000：閏年（能被 400 整除）✓
# - 1900：平年（能被 100 整除但不能被 400 整除）✓
# - 2024：閏年（能被 4 整除但不能被 100 整除）✓
# - 2023：平年（不能被 4 整除）✓
#
# ---

# %% [markdown]
# ### 習題 6：數字正負判斷 🟢
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 6：數字正負判斷 🟢
#
# **題目**：
# 判斷一個數字是正數、負數還是零：
# - 輸入：數字（例如：`number = -5`）
# - 輸出：
#   - 正數：「這是正數」
#   - 負數：「這是負數」
#   - 零：「這是零」
#
# **要求**：
# - 使用 if-elif-else 語句
# - 測試三種情況（-5, 0, 7）

# %%
# 解答
weight = 70  # 公斤
height = 1.75  # 公尺

bmi = weight / (height ** 2)

if bmi < 18.5:
    category = "過輕"
    suggestion = "建議增加營養攝取"
elif bmi < 24:
    category = "正常"
    suggestion = "請維持健康生活習慣"
elif bmi < 27:
    category = "過重"
    suggestion = "建議控制飲食並增加運動"
else:
    category = "肥胖"
    suggestion = "建議諮詢醫師或營養師"

print(f"身高：{height} m")
print(f"體重：{weight} kg")
print(f"BMI：{bmi:.2f}")
print(f"評估：{category}")
print(f"建議：{suggestion}")

# %% [markdown]
# **重點提示**：
# - BMI = 體重(kg) / 身高(m)²
# - 使用 `{bmi:.2f}` 格式化輸出保留 2 位小數
# - 條件從小到大判斷（< 18.5 → < 24 → < 27 → else）
#
# ---

# %% [markdown]
# ### 習題 7：成績等級分類 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ## Part II: 中階題（6 題）🟡
#
# ### 習題 7：成績等級分類 🟡
#
# **題目**：
# 設計一個完整的成績等級系統：
# - 輸入：分數（例如：`score = 85`）
# - 等級標準：
#   - A：90-100 分
#   - B：80-89 分
#   - C：70-79 分
#   - D：60-69 分
#   - F：0-59 分
# - 輸出：「你的成績是 85 分，等級：B」
#
# **要求**：
# - 使用 if-elif-else 鏈
# - 考慮邊界值和順序問題

# %%
# 解答
correct_username = "admin"
correct_password = "python123"

username = input("使用者名稱：")
password = input("密碼：")

if username == correct_username and password == correct_password:
    print("✅ 登入成功！")
    print(f"歡迎，{username}")
elif username != correct_username and password != correct_password:
    print("❌ 登入失敗：使用者名稱和密碼都錯誤")
elif username != correct_username:
    print("❌ 登入失敗：使用者名稱錯誤")
else:
    print("❌ 登入失敗：密碼錯誤")

# %% [markdown]
# **安全性提示**：
# - 實際應用中不應該明確告知哪個欄位錯誤（避免洩漏資訊）
# - 密碼應該加密儲存
# - 應該限制登入嘗試次數
#
# ---

# %% [markdown]
# ### 習題 8：閏年判斷 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 8：閏年判斷 🟡
#
# **題目**：
# 判斷一個年份是否為閏年：
# - 輸入：年份（例如：`year = 2024`）
# - 閏年規則：
#   1. 能被 4 整除，**且**
#   2. 不能被 100 整除，**或者**
#   3. 能被 400 整除
# - 輸出：
#   - 閏年：「2024 年是閏年，2 月有 29 天」
#   - 平年：「2023 年是平年，2 月有 28 天」
#
# **要求**：
# - 組合使用 `and`、`or` 邏輯運算子
# - 測試特殊年份（1900, 2000, 2024）

# %%
# 解答
print("溫度轉換程式")
print("1. 攝氏轉華氏")
print("2. 華氏轉攝氏")

choice = input("請選擇（1 或 2）：")
temperature = float(input("請輸入溫度："))

if choice == "1":
    result = temperature * 9/5 + 32
    print(f"{temperature}°C = {result:.2f}°F")
elif choice == "2":
    result = (temperature - 32) * 5/9
    print(f"{temperature}°F = {result:.2f}°C")
else:
    print("❌ 輸入錯誤，請選擇 1 或 2")

# %% [markdown]
# **常見錯誤**：
# - ❌ 忘記處理無效輸入（非 1 或 2）
# - ❌ 公式錯誤（運算順序）
# - ❌ 忘記型態轉換（input 返回字串）
#
# ---

# %% [markdown]
# ### 習題 9：BMI 健康狀況判斷 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 9：BMI 健康狀況判斷 🟡
#
# **題目**：
# 根據 BMI 值判斷健康狀況：
# - 輸入：BMI 值（例如：`bmi = 22.5`）
# - 健康標準：
#   - BMI < 18.5：過輕
#   - 18.5 <= BMI < 24：正常
#   - 24 <= BMI < 27：過重
#   - 27 <= BMI < 30：輕度肥胖
#   - BMI >= 30：中度肥胖
# - 輸出：「你的 BMI 是 22.5，健康狀況：正常」
#
# **要求**：
# - 使用範圍比較（如：`18.5 <= bmi < 24`）
# - 確保所有範圍都有覆蓋到

# %%
# 解答
num1 = float(input("第一個數字："))
operator = input("運算子（+, -, *, /）：")
num2 = float(input("第二個數字："))

if operator == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator == "-":
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator == "*":
    result = num1 * num2
    print(f"{num1} × {num2} = {result}")
elif operator == "/":
    if num2 == 0:
        print("❌ 錯誤：除數不能為零")
    else:
        result = num1 / num2
        print(f"{num1} ÷ {num2} = {result:.2f}")
else:
    print("❌ 錯誤：無效的運算子")

# %% [markdown]
# **重點提示**：
# - 除法前必須檢查除數是否為零
# - 使用巢狀條件處理特殊情況
# - 處理無效運算子輸入
#
# ---

# %% [markdown]
# ### 習題 10：三角形類型判斷 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 10：三角形類型判斷 🟡
#
# **題目**：
# 判斷三個邊長能否構成三角形，以及三角形的類型：
# - 輸入：三邊長（例如：`a = 3`, `b = 4`, `c = 5`）
# - 判斷步驟：
#   1. 是否能構成三角形（任意兩邊之和 > 第三邊）
#   2. 如果可以，判斷類型：
#      - 等邊三角形：三邊相等
#      - 等腰三角形：兩邊相等
#      - 一般三角形：三邊都不等
# - 輸出範例：
#   - 「邊長 3, 4, 5 可以構成三角形，類型：一般三角形」
#   - 「邊長 1, 2, 5 無法構成三角形」
#
# **要求**：
# - 使用巢狀條件判斷
# - 先判斷是否為三角形，再判斷類型

# %%
# 解答
age = int(input("您的年齡："))
rating = input("電影分級（G, PG, R）：").upper()
with_parent = input("是否有家長陪同？(Y/N)：").upper() == "Y"

if rating == "G":
    print("✅ 普遍級，所有人都可觀看")
elif rating == "PG":
    if age >= 12:
        print("✅ 保護級，12 歲以上可觀看")
    elif with_parent:
        print("✅ 保護級，未滿 12 歲需家長陪同，已有家長陪同")
    else:
        print("❌ 保護級，未滿 12 歲需家長陪同")
elif rating == "R":
    if age >= 18:
        print("✅ 限制級，18 歲以上可觀看")
    else:
        print("❌ 限制級，未滿 18 歲不得觀看")
else:
    print("❌ 錯誤：無效的分級")

# %% [markdown]
# **技巧提示**：
# - 使用 `.upper()` 統一大小寫
# - 巢狀條件處理複雜邏輯
# - 清楚的輸出訊息
#
# ---

# %% [markdown]
# ### 習題 11：購物優惠計算 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 11：購物優惠計算 🟡
#
# **題目**：
# 設計購物優惠系統：
# - 輸入：
#   - 購買金額（例如：`amount = 1200`）
#   - 是否為會員（例如：`is_member = True`）
# - 優惠規則：
#   - 會員且購買 >= 1000：9 折
#   - 會員且購買 >= 500：95 折
#   - 非會員且購買 >= 1000：95 折
#   - 其他情況：無優惠
# - 輸出：
#   ```
#   原價：1200 元
#   會員身份：是
#   優惠：9 折
#   實付：1080 元
#   節省：120 元
#   ```
#
# **要求**：
# - 組合多個條件判斷
# - 計算折扣後價格和節省金額

# %%
# 習題 11 解答：購物優惠計算
amount = float(input("購買金額："))
is_member = input("是否為會員 (Y/N)：").strip().upper() == "Y"
if is_member and amount >= 1000:
    discount = 0.9
elif is_member and amount >= 500:
    discount = 0.95
elif (not is_member) and amount >= 1000:
    discount = 0.95
else:
    discount = 1.0
payable = amount * discount
saved = amount - payable
print(f"原價：{amount:.0f} 元")
print(f"會員身份：{'是' if is_member else '否'}")
print(f"優惠：{discount*100:.0f}%")
print(f"實付：{payable:.0f} 元")
print(f"節省：{saved:.0f} 元")

# %% [markdown]
# ### 習題 12：季節判斷 🟡
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 12：季節判斷 🟡
#
# **題目**：
# 根據月份判斷季節：
# - 輸入：月份（例如：`month = 7`）
# - 季節劃分：
#   - 春季：3, 4, 5 月
#   - 夏季：6, 7, 8 月
#   - 秋季：9, 10, 11 月
#   - 冬季：12, 1, 2 月
# - 輸出：「7 月是夏季」
# - 錯誤處理：如果月份不在 1-12 範圍，輸出「無效的月份」
#
# **要求**：
# - 使用 `in` 運算子檢查月份
# - 處理邊界情況

# %%
# 習題 12 解答：月份判斷季節
month = int(input("請輸入月份 (1-12)："))
if month not in range(1, 13):
    print("無效的月份")
elif month in (3, 4, 5):
    print(f"{month} 月是春季")
elif month in (6, 7, 8):
    print(f"{month} 月是夏季")
elif month in (9, 10, 11):
    print(f"{month} 月是秋季")
else:
    print(f"{month} 月是冬季")

# %% [markdown]
# ### 習題 13：電費計算系統 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ## Part III: 進階題（6 題）🔴
#
# ### 習題 13：電費計算系統 🔴
#
# **題目**：
# 設計台電夏季電費計算系統：
# - 輸入：用電度數（例如：`usage = 350`）
# - 費率級距：
#   - 0-120 度：每度 2.1 元
#   - 121-330 度：每度 3.02 元
#   - 331-500 度：每度 4.39 元
#   - 501-700 度：每度 5.44 元
#   - 701 度以上：每度 6.16 元
# - 輸出範例：
#   ```
#   用電度數：350 度
#   電費明細：
#     第 1 級距 (0-120 度)：120 度 × 2.1 = 252.0 元
#     第 2 級距 (121-330 度)：210 度 × 3.02 = 634.2 元
#     第 3 級距 (331-350 度)：20 度 × 4.39 = 87.8 元
#   總電費：974.0 元
#   ```
#
# **要求**：
# - 使用累進計費邏輯
# - 詳細顯示各級距計算過程

# %%
# 習題 13 解答：台電夏季電費計算
usage = float(input("請輸入用電度數："))
remaining = usage
stages = [
    (120, 2.1),
    (210, 3.02),
    (170, 4.39),
    (200, 5.44),
    (float('inf'), 6.16)
]
print(f"\n用電度數：{usage:.0f} 度")
print("電費明細：")
total = 0
start = 0
for idx, (limit, rate) in enumerate(stages, start=1):
    take = min(remaining, limit)
    if take <= 0:
        break
    stage_amount = take * rate
    total += stage_amount
    end = start + take
    print(f"  第 {idx} 級距 ({start+1 if start>0 else 0}-{int(end)} 度)：{take:.0f} 度 × {rate} = {stage_amount:.1f} 元")
    remaining -= take
    start += take
print(f"總電費：{total:.1f} 元")

# %% [markdown]
# ### 習題 14：簡易計算機 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 14：簡易計算機 🔴
#
# **題目**：
# 設計一個支援四則運算的簡易計算機：
# - 輸入：
#   - 第一個數字（例如：`num1 = 10`）
#   - 運算符號（例如：`operator = "/"`）
#   - 第二個數字（例如：`num2 = 3`）
# - 支援運算：`+`, `-`, `*`, `/`
# - 特殊處理：
#   - 除法運算要檢查除數不為零
#   - 無效運算符號要提示錯誤
# - 輸出範例：
#   ```
#   計算：10 / 3
#   結果：3.333333333333333
#   （或）
#   錯誤：除數不能為零
#   （或）
#   錯誤：不支援的運算符號
#   ```
#
# **要求**：
# - 使用 if-elif-else 處理不同運算符
# - 巢狀條件處理特殊情況

# %%
# 習題 14 解答：支援四則運算的計算機
num1 = float(input("第一個數字："))
operator = input("運算子 (+ - * /)：")
num2 = float(input("第二個數字："))
if operator == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
elif operator == "-":
    result = num1 - num2
    print(f"{num1} - {num2} = {result}")
elif operator == "*":
    result = num1 * num2
    print(f"{num1} × {num2} = {result}")
elif operator == "/":
    if num2 == 0:
        print("❌ 錯誤：除數不能為零")
    else:
        result = num1 / num2
        print(f"{num1} ÷ {num2} = {result}")
else:
    print("❌ 錯誤：不支援的運算符號")

# %% [markdown]
# ### 習題 15：學生獎學金評選 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 15：學生獎學金評選 🔴
#
# **題目**：
# 設計學生獎學金評選系統：
# - 輸入：
#   - 學期成績（例如：`gpa = 3.8`）
#   - 出席率（例如：`attendance = 95`）
#   - 服務時數（例如：`service_hours = 20`）
#   - 是否為低收入戶（例如：`low_income = False`）
# - 獎學金標準：
#   - **特優獎學金**：GPA >= 3.8 且 出席率 >= 95% 且 服務時數 >= 30
#   - **優秀獎學金**：GPA >= 3.5 且 出席率 >= 90% 且 服務時數 >= 20
#   - **勤學獎學金**：GPA >= 3.2 且 出席率 >= 85%
#   - **扶助獎學金**：低收入戶 且 GPA >= 2.5 且 出席率 >= 80%
#   - **無獎學金**：不符合任何條件
# - 輸出範例：
#   ```
#   學生資料：
#     GPA：3.8
#     出席率：95%
#     服務時數：20 小時
#     低收入戶：否
#   評選結果：優秀獎學金
#   ```
#
# **要求**：
# - 複雜邏輯條件組合
# - 優先順序：特優 > 優秀 > 勤學 > 扶助

# %%
# 解答（完整版參考 lecture 範例 8）
student_name = "王小明"
score = 88
attendance_rate = 0.85
has_homework = True

print(f"===== {student_name} 的成績評估 =====")
print(f"考試分數：{score}")
print(f"出席率：{attendance_rate * 100:.0f}%")
print(f"作業繳交：{'是' if has_homework else '否'}")
print("\n--- 評估結果 ---")

# 基本成績評級
if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 60:
    grade = "D"
else:
    grade = "F"

# 出席率檢查
if attendance_rate < 0.7:
    print("⚠️ 警告：出席率不足 70%")
    grade = "F"

# 作業加分
if has_homework and score >= 60:
    bonus = 5
    final_score = min(score + bonus, 100)
    print(f"✅ 作業加分：+{bonus} 分")
else:
    final_score = score

print(f"\n最終成績：{grade} ({final_score} 分)")

# %% [markdown]
# **學習重點**：
# - 多層條件判斷的組織方式
# - 條件內修改變數值
# - 使用 `min()` 限制最高分數
# - 清晰的輸出格式
#
# ---

# %% [markdown]
# ### 習題 16：密碼強度檢測 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 16：密碼強度檢測 🔴
#
# **題目**：
# 設計完整的密碼強度檢測系統：
# - 輸入：密碼字串（需要模擬，例如：設定各種布林變數）
# - 檢測項目：
#   ```python
#   # 模擬密碼分析結果
#   password_length = 10
#   has_uppercase = True    # 包含大寫字母
#   has_lowercase = True    # 包含小寫字母
#   has_digit = True        # 包含數字
#   has_special = False     # 包含特殊字元
#   has_common_word = False # 包含常見詞彙
#   ```
# - 強度等級：
#   - **很強**：長度 >= 12，包含 4 種字元類型，無常見詞彙
#   - **強**：長度 >= 10，包含 3 種字元類型，無常見詞彙
#   - **中等**：長度 >= 8，包含 2 種字元類型
#   - **弱**：長度 >= 6，包含至少 1 種字元類型
#   - **很弱**：不符合以上條件
# - 輸出範例：
#   ```
#   密碼強度分析：
#     長度：10 字元 ✓
#     大寫字母：有 ✓
#     小寫字母：有 ✓
#     數字：有 ✓
#     特殊字元：無 ✗
#     常見詞彙：無 ✓
#   強度等級：強
#   建議：添加特殊字元可提升安全性
#   ```
#
# **要求**：
# - 計算字元類型數量
# - 複雜的條件判斷邏輯
# - 提供改善建議

# %% [markdown]
# ## 🎯 總結與檢核
#
# ### 完成檢核清單
#
# 完成本章學習後，你應該能夠：
#
# **基礎能力**
# - [ ] 正確使用 if/elif/else 語法
# - [ ] 理解條件表達式與布林值
# - [ ] 正確使用比較運算子（>, <, ==, !=, >=, <=）
# - [ ] 正確使用邏輯運算子（and, or, not）
# - [ ] 寫出正確縮排的程式碼
#
# **進階能力**
# - [ ] 設計多重條件判斷邏輯
# - [ ] 使用巢狀條件處理複雜情況
# - [ ] 優化條件判斷順序
# - [ ] 使用三元運算子簡化程式
# - [ ] 處理邊界情況和異常輸入
#
# **應用能力**
# - [ ] 分析實際問題並設計條件邏輯
# - [ ] 整合條件判斷與其他知識（變數、運算、I/O）
# - [ ] 除錯常見的條件判斷錯誤
# - [ ] 編寫清晰、可維護的條件判斷程式碼
#
# ---

# %% [markdown]
# ## 📝 學習建議
#
# ### 後續學習路徑
#
# 1. **已完成本章**：
#    - ✅ 完成 `quiz.ipynb` 自我測驗（28 題）
#    - ✅ 分數 ≥ 21/28 (75%) 可進入下一章
#
# 2. **下一步**：
#    - 📖 **Chapter 5: 迴圈基礎**（將條件判斷與重複執行結合）
#    - 🎯 **Milestone 2: 猜數字遊戲**（實際應用條件判斷）
#
# 3. **需要加強**：
#    - 如果 quiz 分數 < 21，建議重新學習：
#      - 重讀 `01-lecture.ipynb`
#      - 完成 `02-worked-examples.ipynb`
#      - 練習 `03-practice.ipynb`
#
# ---

# %% [markdown]
# ## 💡 常見問題與除錯技巧
#
# ### Q1: 為什麼條件不成立？
# **A**: 檢查：
# 1. 是否使用 `==` 而非 `=`
# 2. 變數型態是否正確（字串 vs 數字）
# 3. 條件順序是否正確
#
# ### Q2: 縮排錯誤怎麼辦？
# **A**:
# 1. 確保使用 4 個空格（不要用 Tab）
# 2. 同一區塊的程式碼必須有相同縮排
# 3. 使用編輯器的「顯示空白字元」功能
#
# ### Q3: 如何簡化複雜條件？
# **A**:
# 1. 使用括號明確優先順序
# 2. 將複雜條件拆分成多個變數
# 3. 使用 De Morgan's Law 簡化 not 運算
#
# ---
#
# **恭喜完成 Chapter 4 所有練習！繼續加油！** 🎉

# %% [markdown]
# ### 習題 17：停車費計算系統 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 17：停車費計算系統 🔴
#
# **題目**：
# 設計完整的停車費計算系統：
# - 輸入：
#   - 停車時數（例如：`hours = 5.5`）
#   - 車輛類型（例如：`vehicle_type = "car"`）
#   - 是否為假日（例如：`is_holiday = True`）
#   - 是否有月票（例如：`has_monthly_pass = False`）
# - 費率表：
#   - **汽車 (car)**：
#     - 平日：前 2 小時 30 元/時，之後 20 元/時
#     - 假日：前 2 小時 40 元/時，之後 30 元/時
#   - **機車 (motorcycle)**：
#     - 平日：20 元/時
#     - 假日：25 元/時
#   - **月票**：享 8 折優惠
#   - **不足 1 小時以 1 小時計算**
# - 輸出範例：
#   ```
#   停車資訊：
#     車輛類型：汽車
#     停車時間：5.5 小時（計費 6 小時）
#     日期類型：假日
#     月票：無
#   費用計算：
#     前 2 小時：2 × 40 = 80 元
#     後 4 小時：4 × 30 = 120 元
#     小計：200 元
#     月票優惠：無
#   應繳費用：200 元
#   ```
#
# **要求**：
# - 處理小數時間的無條件進位
# - 複雜的階梯計費邏輯
# - 多重條件組合

# %%
# 習題 17 解答：停車費計算系統
import math
hours = float(input("停車時數："))
vehicle_type = input("車輛類型 (car/motorcycle)：").strip().lower()
is_holiday = input("是否為假日 (Y/N)：").strip().upper() == "Y"
has_monthly_pass = input("是否有月票 (Y/N)：").strip().upper() == "Y"
billed_hours = math.ceil(hours)
print("\n停車資訊：")
print(f"  車輛類型：{vehicle_type}")
print(f"  停車時間：{hours} 小時（計費 {billed_hours} 小時）")
print(f"  日期類型：{'假日' if is_holiday else '平日'}")
print(f"  月票：{'有' if has_monthly_pass else '無'}")
charge = 0
if vehicle_type == "car":
    first_rate = 40 if is_holiday else 30
    extra_rate = 30 if is_holiday else 20
    first_hours = min(2, billed_hours)
    extra_hours = max(0, billed_hours - 2)
    if first_hours:
        print(f"  前 {first_hours} 小時：{first_hours} × {first_rate} = {first_hours * first_rate} 元")
        charge += first_hours * first_rate
    if extra_hours:
        print(f"  後 {extra_hours} 小時：{extra_hours} × {extra_rate} = {extra_hours * extra_rate} 元")
        charge += extra_hours * extra_rate
elif vehicle_type == "motorcycle":
    rate = 25 if is_holiday else 20
    charge = billed_hours * rate
    print(f"  機車每小時 {rate} 元：{billed_hours} × {rate} = {charge} 元")
else:
    print("  未知車種，無法計費")
if has_monthly_pass:
    print("  月票優惠：8 折")
    charge *= 0.8
print(f"應繳費用：{charge:.0f} 元")

# %% [markdown]
# ### 習題 18：所得稅計算器 🔴
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 18：所得稅計算器 🔴
#
# **題目**：
# 設計個人所得稅計算器：
# - 輸入：
#   - 年收入（例如：`annual_income = 800000`）
#   - 撫養人數（例如：`dependents = 2`）
#   - 婚姻狀況（例如：`married = True`）
# - 稅率級距（簡化版）：
#   - 0-540,000：免稅
#   - 540,001-1,210,000：5%
#   - 1,210,001-2,420,000：12%
#   - 2,420,001-4,530,000：20%
#   - 4,530,001 以上：30%
# - 扣除額：
#   - 標準扣除額：單身 120,000，夫妻 240,000
#   - 免稅額：每人 92,000（本人 + 撫養人數）
# - 輸出範例：
#   ```
#   所得稅試算：
#     年收入：800,000 元
#     標準扣除額：240,000 元（夫妻）
#     免稅額：276,000 元（3 人 × 92,000）
#     課稅所得：284,000 元
#   稅額計算：
#     免稅級距：0 元
#     應納稅額：0 元（課稅所得未超過 540,000）
#   ```
#
# **要求**：
# - 累進稅率計算
# - 複雜的扣除額邏輯
# - 條件判斷與數值計算結合

# %%
# 習題 18 解答：所得稅試算
annual_income = float(input("年收入："))
dependents = int(input("撫養人數："))
married = input("婚姻狀況 (Y=已婚)：").strip().upper() == "Y"
standard_deduction = 240000 if married else 120000
exemption = (dependents + 1) * 92000
print(f"標準扣除額：{standard_deduction:,.0f} 元")
print(f"免稅額：{exemption:,.0f} 元")
taxable_income = max(0, annual_income - standard_deduction - exemption)
print(f"課稅所得：{taxable_income:,.0f} 元")
brackets = [
    (540000, 0.0),
    (1210000, 0.05),
    (2420000, 0.12),
    (4530000, 0.20),
    (float('inf'), 0.30)
]
tax = 0
previous = 0
for limit, rate in brackets:
    if taxable_income <= previous:
        break
    taxable_at_bracket = min(taxable_income, limit) - previous
    tax += taxable_at_bracket * rate
    previous = limit
print(f"應納稅額：{tax:,.0f} 元")

# %% [markdown]
# ### 習題 19：智慧家居控制系統 🟣
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ## Part IV: 挑戰題（2 題）🟣
#
# ### 習題 19：智慧家居控制系統 🟣
#
# **題目**：
# 設計智慧家居自動控制系統：
# - 輸入感測器資料：
#   ```python
#   # 環境感測器
#   indoor_temp = 28        # 室內溫度
#   outdoor_temp = 35       # 室外溫度
#   humidity = 70           # 濕度 (%)
#   light_level = 200       # 光線強度 (lux)
#
#   # 時間與狀態
#   current_hour = 14       # 24 小時制
#   someone_home = True     # 是否有人在家
#   sleep_mode = False      # 是否為睡眠模式
#   energy_save = False     # 是否開啟節能模式
#   ```
# - 控制邏輯：
#   - **冷氣控制**：
#     - 有人在家且室內溫度 > 26°C：開啟
#     - 睡眠模式：設定 28°C
#     - 節能模式：設定 27°C
#     - 其他：設定 25°C
#   - **燈光控制**：
#     - 光線不足（< 300 lux）且有人在家：開啟
#     - 睡眠模式：微弱燈光
#     - 23:00-06:00：夜燈模式
#   - **除濕機控制**：
#     - 濕度 > 65% 且有人在家：開啟
#   - **窗簾控制**：
#     - 室外溫度 > 32°C 且光線強烈（> 500 lux）：關閉
#     - 睡眠模式：關閉
#     - 其他時間：開啟
# - 輸出範例：
#   ```
#   智慧家居控制狀態：
#
#   環境資訊：
#     室內溫度：28°C
#     室外溫度：35°C
#     濕度：70%
#     光線：200 l

# %%
# 習題 19 解答：智慧家居控制
indoor_temp = float(input("室內溫度："))
outdoor_temp = float(input("室外溫度："))
humidity = float(input("濕度 (% )："))
light_level = float(input("光線強度 (lux)："))
current_hour = int(input("目前時間 (0-23)："))
someone_home = input("是否有人在家 (Y/N)：").strip().upper() == "Y"
sleep_mode = input("是否為睡眠模式 (Y/N)：").strip().upper() == "Y"
energy_save = input("是否開啟節能模式 (Y/N)：").strip().upper() == "Y"

# 冷氣控制
if someone_home and indoor_temp > 26:
    ac_status = "開啟"
    if sleep_mode:
        ac_temp = 28
    elif energy_save:
        ac_temp = 27
    else:
        ac_temp = 25
else:
    ac_status = "關閉"
    ac_temp = None

# 燈光控制
if sleep_mode:
    light_status = "微弱燈光"
elif current_hour >= 23 or current_hour < 6:
    light_status = "夜燈模式"
elif someone_home and light_level < 300:
    light_status = "開啟（光線不足）"
else:
    light_status = "關閉"

# 除濕機
if someone_home and humidity > 65:
    dehumidifier = "開啟"
else:
    dehumidifier = "關閉"

# 窗簾
if sleep_mode or (outdoor_temp > 32 and light_level > 500):
    curtain = "關閉"
else:
    curtain = "開啟"

# 能耗評估
devices_on = sum([
    ac_status == "開啟",
    light_status.startswith("開啟") or light_status.startswith("微弱") or light_status.startswith("夜燈"),
    dehumidifier == "開啟"
])
if devices_on == 0:
    energy_level = "低"
elif devices_on == 1:
    energy_level = "中"
else:
    energy_level = "高"

print("\n智慧家居控制狀態：")
print(f"冷氣：{ac_status}" + (f"（設定 {ac_temp}°C）" if ac_temp else ""))
print(f"燈光：{light_status}")
print(f"除濕機：{dehumidifier}")
print(f"窗簾：{curtain}")
print(f"預估耗電：{energy_level}")

# %% [markdown]
# ### 習題 20：投資組合風險評估 🟣
#
# > 題目摘要（摘自 `04-exercises.ipynb`）：
#
# ---
#
# ### 習題 20：投資組合風險評估 🟣
#
# **題目**：
# 設計投資組合風險評估系統：
# - 輸入投資者資料：
#   ```python
#   # 個人資料
#   age = 35
#   annual_income = 1200000      # 年收入
#   investment_experience = 5    # 投資經驗（年）
#   risk_tolerance = "medium"    # 風險承受度：low/medium/high
#
#   # 財務狀況
#   total_assets = 5000000       # 總資產
#   debt_ratio = 0.3             # 負債比例
#   emergency_fund = 600000      # 緊急準備金
#
#   # 投資目標
#   investment_period = 10       # 投資期間（年）
#   target_return = 0.08         # 目標報酬率
#   has_dependents = True        # 是否有撫養責任
#   ```
# - 評估邏輯：
#   - **年齡係數**：
#     - < 30：積極型 (1.2)
#     - 30-50：穩健型 (1.0)
#     - > 50：保守型 (0.8)
#   - **財務穩定度**：
#     - 負債比 < 0.3 且緊急基金 >= 年收入×6個月：穩定
#     - 負債比 < 0.5 且緊急基金 >= 年收入×3個月：一般
#     - 其他：不穩定
#   - **建議股票配置比例**：
#     - 基礎比例 = min(100 - 年齡, 80)
#     - 根據風險承受度調整 (low: -20%, medium: 0%, high: +10%)
#     - 根據財務穩定度調整 (不穩定: -

# %%
# 習題 20 解答：投資組合風險評估
age = int(input("年齡："))
annual_income = float(input("年收入："))
investment_experience = int(input("投資經驗（年）："))
risk_tolerance = input("風險承受度 (low/medium/high)：").strip().lower()
total_assets = float(input("總資產："))
debt_ratio = float(input("負債比例 (0-1)："))
emergency_fund = float(input("緊急準備金："))
investment_period = int(input("投資期間（年）："))
target_return = float(input("目標報酬率 (0-1)："))
has_dependents = input("是否有撫養責任 (Y/N)：").strip().upper() == "Y"

base_stock = min(80, max(0, 100 - age))
if risk_tolerance == "low":
    base_stock -= 20
elif risk_tolerance == "high":
    base_stock += 10

six_month_income = annual_income * 0.5
three_month_income = annual_income * 0.25
if debt_ratio < 0.3 and emergency_fund >= six_month_income:
    stability = "穩定"
    base_stock += 5
elif debt_ratio < 0.5 and emergency_fund >= three_month_income:
    stability = "一般"
else:
    stability = "不穩定"
    base_stock -= 15

if has_dependents:
    base_stock -= 10
recommended_stock = min(90, max(10, base_stock))
print("\n投資風險評估報告：")
print(f"  年齡：{age} 歲，風險承受度：{risk_tolerance}")
print(f"  財務穩定度：{stability}")
print(f"  建議股票配置比例：約 {recommended_stock:.0f}%")
print(f"  建議債券/現金比例：約 {100 - recommended_stock:.0f}%")
