# %% [markdown]
# # Chapter 4: 條件判斷 | Conditionals
#
# ## ✍️ 課後習題 | Homework Exercises
#
# ---
#
# ## 💡 本檔案目的
#
# 本檔案提供 **20 個課後習題**，供學生獨立完成：
# - **難度分級**：基礎（🟢）→ 中階（🟡）→ 進階（🔴）→ 挑戰（🟣）
# - **自主練習**：無提示，完全靠自己思考
# - **答案對照**：請參考 `05-solutions.ipynb`
#
# ---
#
# ## 📝 作業規範
#
# 1. **禁止複製貼上**：所有程式碼需自己撰寫
# 2. **測試程式碼**：每題完成後執行 cell 確認結果
# 3. **對照答案**：完成所有題目後再看 `05-solutions.ipynb`
# 4. **記錄時間**：記錄完成每題所需時間（自我評估）
#
# ---

# %% [markdown]
# ## Part I: 基礎題（6 題）🟢
#
# ### 習題 1：基本 if 語句 🟢
#
# **題目**：
# 寫一個程式，判斷學生是否及格：
# - 輸入：分數（例如：`score = 75`）
# - 條件：分數 >= 60 為及格
# - 輸出：如果及格，印出「恭喜！你及格了！」
#
# **要求**：
# - 使用簡單的 if 語句
# - 測試不同分數值（60, 59, 85）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 2：if-else 二選一 🟢
#
# **題目**：
# 設計一個年齡判斷程式：
# - 輸入：年齡（例如：`age = 17`）
# - 判斷：是否已成年（18 歲以上）
# - 輸出：
#   - 已成年：「你已經成年，可以投票了！」
#   - 未成年：「你還未成年，需要等到 18 歲才能投票。」
#
# **要求**：
# - 使用 if-else 語句
# - 測試邊界值（17, 18, 20）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 3：比較運算子練習 🟢
#
# **題目**：
# 比較兩個數字的大小關係：
# - 輸入：兩個數字（例如：`a = 25`, `b = 30`）
# - 輸出：所有可能的比較結果
#
# **要求**：
# 使用 6 種比較運算子，輸出格式如下：
# ```
# 25 > 30: False
# 25 < 30: True
# 25 >= 30: False
# 25 <= 30: True
# 25 == 30: False
# 25 != 30: True
# ```

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 4：邏輯運算子基礎 🟢
#
# **題目**：
# 設計一個簡單的密碼檢查程式：
# - 給定條件：
#   - `password_correct = True`（密碼正確）
#   - `account_locked = False`（帳戶未鎖定）
# - 判斷：只有當密碼正確**且**帳戶未鎖定時才能登入
# - 輸出：
#   - 可以登入：「登入成功！」
#   - 不能登入：「登入失敗！」
#
# **要求**：
# 使用 `and` 邏輯運算子

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 5：溫度判斷 🟢
#
# **題目**：
# 根據溫度決定穿衣建議：
# - 輸入：溫度（例如：`temperature = 15`）
# - 判斷標準：
#   - 溫度 < 10°C：「很冷，建議穿厚外套」
#   - 溫度 >= 10°C：「不會太冷，穿一般衣服即可」
#
# **要求**：
# - 使用 if-else 語句
# - 測試不同溫度（5, 10, 15）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 6：數字正負判斷 🟢
#
# **題目**：
# 判斷一個數字是正數、負數還是零：
# - 輸入：數字（例如：`number = -5`）
# - 輸出：
#   - 正數：「這是正數」
#   - 負數：「這是負數」
#   - 零：「這是零」
#
# **要求**：
# - 使用 if-elif-else 語句
# - 測試三種情況（-5, 0, 7）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ## Part II: 中階題（6 題）🟡
#
# ### 習題 7：成績等級分類 🟡
#
# **題目**：
# 設計一個完整的成績等級系統：
# - 輸入：分數（例如：`score = 85`）
# - 等級標準：
#   - A：90-100 分
#   - B：80-89 分
#   - C：70-79 分
#   - D：60-69 分
#   - F：0-59 分
# - 輸出：「你的成績是 85 分，等級：B」
#
# **要求**：
# - 使用 if-elif-else 鏈
# - 考慮邊界值和順序問題

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 8：閏年判斷 🟡
#
# **題目**：
# 判斷一個年份是否為閏年：
# - 輸入：年份（例如：`year = 2024`）
# - 閏年規則：
#   1. 能被 4 整除，**且**
#   2. 不能被 100 整除，**或者**
#   3. 能被 400 整除
# - 輸出：
#   - 閏年：「2024 年是閏年，2 月有 29 天」
#   - 平年：「2023 年是平年，2 月有 28 天」
#
# **要求**：
# - 組合使用 `and`、`or` 邏輯運算子
# - 測試特殊年份（1900, 2000, 2024）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 9：BMI 健康狀況判斷 🟡
#
# **題目**：
# 根據 BMI 值判斷健康狀況：
# - 輸入：BMI 值（例如：`bmi = 22.5`）
# - 健康標準：
#   - BMI < 18.5：過輕
#   - 18.5 <= BMI < 24：正常
#   - 24 <= BMI < 27：過重
#   - 27 <= BMI < 30：輕度肥胖
#   - BMI >= 30：中度肥胖
# - 輸出：「你的 BMI 是 22.5，健康狀況：正常」
#
# **要求**：
# - 使用範圍比較（如：`18.5 <= bmi < 24`）
# - 確保所有範圍都有覆蓋到

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 10：三角形類型判斷 🟡
#
# **題目**：
# 判斷三個邊長能否構成三角形，以及三角形的類型：
# - 輸入：三邊長（例如：`a = 3`, `b = 4`, `c = 5`）
# - 判斷步驟：
#   1. 是否能構成三角形（任意兩邊之和 > 第三邊）
#   2. 如果可以，判斷類型：
#      - 等邊三角形：三邊相等
#      - 等腰三角形：兩邊相等
#      - 一般三角形：三邊都不等
# - 輸出範例：
#   - 「邊長 3, 4, 5 可以構成三角形，類型：一般三角形」
#   - 「邊長 1, 2, 5 無法構成三角形」
#
# **要求**：
# - 使用巢狀條件判斷
# - 先判斷是否為三角形，再判斷類型

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 11：購物優惠計算 🟡
#
# **題目**：
# 設計購物優惠系統：
# - 輸入：
#   - 購買金額（例如：`amount = 1200`）
#   - 是否為會員（例如：`is_member = True`）
# - 優惠規則：
#   - 會員且購買 >= 1000：9 折
#   - 會員且購買 >= 500：95 折
#   - 非會員且購買 >= 1000：95 折
#   - 其他情況：無優惠
# - 輸出：
#   ```
#   原價：1200 元
#   會員身份：是
#   優惠：9 折
#   實付：1080 元
#   節省：120 元
#   ```
#
# **要求**：
# - 組合多個條件判斷
# - 計算折扣後價格和節省金額

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 12：季節判斷 🟡
#
# **題目**：
# 根據月份判斷季節：
# - 輸入：月份（例如：`month = 7`）
# - 季節劃分：
#   - 春季：3, 4, 5 月
#   - 夏季：6, 7, 8 月
#   - 秋季：9, 10, 11 月
#   - 冬季：12, 1, 2 月
# - 輸出：「7 月是夏季」
# - 錯誤處理：如果月份不在 1-12 範圍，輸出「無效的月份」
#
# **要求**：
# - 使用 `in` 運算子檢查月份
# - 處理邊界情況

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ## Part III: 進階題（6 題）🔴
#
# ### 習題 13：電費計算系統 🔴
#
# **題目**：
# 設計台電夏季電費計算系統：
# - 輸入：用電度數（例如：`usage = 350`）
# - 費率級距：
#   - 0-120 度：每度 2.1 元
#   - 121-330 度：每度 3.02 元
#   - 331-500 度：每度 4.39 元
#   - 501-700 度：每度 5.44 元
#   - 701 度以上：每度 6.16 元
# - 輸出範例：
#   ```
#   用電度數：350 度
#   電費明細：
#     第 1 級距 (0-120 度)：120 度 × 2.1 = 252.0 元
#     第 2 級距 (121-330 度)：210 度 × 3.02 = 634.2 元
#     第 3 級距 (331-350 度)：20 度 × 4.39 = 87.8 元
#   總電費：974.0 元
#   ```
#
# **要求**：
# - 使用累進計費邏輯
# - 詳細顯示各級距計算過程

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 14：簡易計算機 🔴
#
# **題目**：
# 設計一個支援四則運算的簡易計算機：
# - 輸入：
#   - 第一個數字（例如：`num1 = 10`）
#   - 運算符號（例如：`operator = "/"`）
#   - 第二個數字（例如：`num2 = 3`）
# - 支援運算：`+`, `-`, `*`, `/`
# - 特殊處理：
#   - 除法運算要檢查除數不為零
#   - 無效運算符號要提示錯誤
# - 輸出範例：
#   ```
#   計算：10 / 3
#   結果：3.333333333333333
#   （或）
#   錯誤：除數不能為零
#   （或）
#   錯誤：不支援的運算符號
#   ```
#
# **要求**：
# - 使用 if-elif-else 處理不同運算符
# - 巢狀條件處理特殊情況

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 15：學生獎學金評選 🔴
#
# **題目**：
# 設計學生獎學金評選系統：
# - 輸入：
#   - 學期成績（例如：`gpa = 3.8`）
#   - 出席率（例如：`attendance = 95`）
#   - 服務時數（例如：`service_hours = 20`）
#   - 是否為低收入戶（例如：`low_income = False`）
# - 獎學金標準：
#   - **特優獎學金**：GPA >= 3.8 且 出席率 >= 95% 且 服務時數 >= 30
#   - **優秀獎學金**：GPA >= 3.5 且 出席率 >= 90% 且 服務時數 >= 20
#   - **勤學獎學金**：GPA >= 3.2 且 出席率 >= 85%
#   - **扶助獎學金**：低收入戶 且 GPA >= 2.5 且 出席率 >= 80%
#   - **無獎學金**：不符合任何條件
# - 輸出範例：
#   ```
#   學生資料：
#     GPA：3.8
#     出席率：95%
#     服務時數：20 小時
#     低收入戶：否
#   評選結果：優秀獎學金
#   ```
#
# **要求**：
# - 複雜邏輯條件組合
# - 優先順序：特優 > 優秀 > 勤學 > 扶助

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 16：密碼強度檢測 🔴
#
# **題目**：
# 設計完整的密碼強度檢測系統：
# - 輸入：密碼字串（需要模擬，例如：設定各種布林變數）
# - 檢測項目：
#   ```python
#   # 模擬密碼分析結果
#   password_length = 10
#   has_uppercase = True    # 包含大寫字母
#   has_lowercase = True    # 包含小寫字母
#   has_digit = True        # 包含數字
#   has_special = False     # 包含特殊字元
#   has_common_word = False # 包含常見詞彙
#   ```
# - 強度等級：
#   - **很強**：長度 >= 12，包含 4 種字元類型，無常見詞彙
#   - **強**：長度 >= 10，包含 3 種字元類型，無常見詞彙
#   - **中等**：長度 >= 8，包含 2 種字元類型
#   - **弱**：長度 >= 6，包含至少 1 種字元類型
#   - **很弱**：不符合以上條件
# - 輸出範例：
#   ```
#   密碼強度分析：
#     長度：10 字元 ✓
#     大寫字母：有 ✓
#     小寫字母：有 ✓
#     數字：有 ✓
#     特殊字元：無 ✗
#     常見詞彙：無 ✓
#   強度等級：強
#   建議：添加特殊字元可提升安全性
#   ```
#
# **要求**：
# - 計算字元類型數量
# - 複雜的條件判斷邏輯
# - 提供改善建議

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 17：停車費計算系統 🔴
#
# **題目**：
# 設計完整的停車費計算系統：
# - 輸入：
#   - 停車時數（例如：`hours = 5.5`）
#   - 車輛類型（例如：`vehicle_type = "car"`）
#   - 是否為假日（例如：`is_holiday = True`）
#   - 是否有月票（例如：`has_monthly_pass = False`）
# - 費率表：
#   - **汽車 (car)**：
#     - 平日：前 2 小時 30 元/時，之後 20 元/時
#     - 假日：前 2 小時 40 元/時，之後 30 元/時
#   - **機車 (motorcycle)**：
#     - 平日：20 元/時
#     - 假日：25 元/時
#   - **月票**：享 8 折優惠
#   - **不足 1 小時以 1 小時計算**
# - 輸出範例：
#   ```
#   停車資訊：
#     車輛類型：汽車
#     停車時間：5.5 小時（計費 6 小時）
#     日期類型：假日
#     月票：無
#   費用計算：
#     前 2 小時：2 × 40 = 80 元
#     後 4 小時：4 × 30 = 120 元
#     小計：200 元
#     月票優惠：無
#   應繳費用：200 元
#   ```
#
# **要求**：
# - 處理小數時間的無條件進位
# - 複雜的階梯計費邏輯
# - 多重條件組合

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 18：所得稅計算器 🔴
#
# **題目**：
# 設計個人所得稅計算器：
# - 輸入：
#   - 年收入（例如：`annual_income = 800000`）
#   - 撫養人數（例如：`dependents = 2`）
#   - 婚姻狀況（例如：`married = True`）
# - 稅率級距（簡化版）：
#   - 0-540,000：免稅
#   - 540,001-1,210,000：5%
#   - 1,210,001-2,420,000：12%
#   - 2,420,001-4,530,000：20%
#   - 4,530,001 以上：30%
# - 扣除額：
#   - 標準扣除額：單身 120,000，夫妻 240,000
#   - 免稅額：每人 92,000（本人 + 撫養人數）
# - 輸出範例：
#   ```
#   所得稅試算：
#     年收入：800,000 元
#     標準扣除額：240,000 元（夫妻）
#     免稅額：276,000 元（3 人 × 92,000）
#     課稅所得：284,000 元
#   稅額計算：
#     免稅級距：0 元
#     應納稅額：0 元（課稅所得未超過 540,000）
#   ```
#
# **要求**：
# - 累進稅率計算
# - 複雜的扣除額邏輯
# - 條件判斷與數值計算結合

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ## Part IV: 挑戰題（2 題）🟣
#
# ### 習題 19：智慧家居控制系統 🟣
#
# **題目**：
# 設計智慧家居自動控制系統：
# - 輸入感測器資料：
#   ```python
#   # 環境感測器
#   indoor_temp = 28        # 室內溫度
#   outdoor_temp = 35       # 室外溫度
#   humidity = 70           # 濕度 (%)
#   light_level = 200       # 光線強度 (lux)
#
#   # 時間與狀態
#   current_hour = 14       # 24 小時制
#   someone_home = True     # 是否有人在家
#   sleep_mode = False      # 是否為睡眠模式
#   energy_save = False     # 是否開啟節能模式
#   ```
# - 控制邏輯：
#   - **冷氣控制**：
#     - 有人在家且室內溫度 > 26°C：開啟
#     - 睡眠模式：設定 28°C
#     - 節能模式：設定 27°C
#     - 其他：設定 25°C
#   - **燈光控制**：
#     - 光線不足（< 300 lux）且有人在家：開啟
#     - 睡眠模式：微弱燈光
#     - 23:00-06:00：夜燈模式
#   - **除濕機控制**：
#     - 濕度 > 65% 且有人在家：開啟
#   - **窗簾控制**：
#     - 室外溫度 > 32°C 且光線強烈（> 500 lux）：關閉
#     - 睡眠模式：關閉
#     - 其他時間：開啟
# - 輸出範例：
#   ```
#   智慧家居控制狀態：
#
#   環境資訊：
#     室內溫度：28°C
#     室外溫度：35°C
#     濕度：70%
#     光線：200 lux
#     時間：14:00
#     有人在家：是
#     睡眠模式：否
#     節能模式：否
#
#   設備控制：
#     冷氣：開啟（設定 25°C）
#     燈光：開啟（光線不足）
#     除濕機：開啟（濕度過高）
#     窗簾：關閉（室外溫度過高）
#
#   預估耗電：中等
#   ```
#
# **要求**：
# - 超複雜的巢狀條件邏輯
# - 多重感測器資料整合
# - 計算預估耗電量（低/中/高）

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---
#
# ### 習題 20：投資組合風險評估 🟣
#
# **題目**：
# 設計投資組合風險評估系統：
# - 輸入投資者資料：
#   ```python
#   # 個人資料
#   age = 35
#   annual_income = 1200000      # 年收入
#   investment_experience = 5    # 投資經驗（年）
#   risk_tolerance = "medium"    # 風險承受度：low/medium/high
#
#   # 財務狀況
#   total_assets = 5000000       # 總資產
#   debt_ratio = 0.3             # 負債比例
#   emergency_fund = 600000      # 緊急準備金
#
#   # 投資目標
#   investment_period = 10       # 投資期間（年）
#   target_return = 0.08         # 目標報酬率
#   has_dependents = True        # 是否有撫養責任
#   ```
# - 評估邏輯：
#   - **年齡係數**：
#     - < 30：積極型 (1.2)
#     - 30-50：穩健型 (1.0)
#     - > 50：保守型 (0.8)
#   - **財務穩定度**：
#     - 負債比 < 0.3 且緊急基金 >= 年收入×6個月：穩定
#     - 負債比 < 0.5 且緊急基金 >= 年收入×3個月：一般
#     - 其他：不穩定
#   - **建議股票配置比例**：
#     - 基礎比例 = min(100 - 年齡, 80)
#     - 根據風險承受度調整 (low: -20%, medium: 0%, high: +10%)
#     - 根據財務穩定度調整 (不穩定: -15%, 一般: 0%, 穩定: +5%)
#     - 有撫養責任: -10%
#     - 最終比例限制在 10%-90% 之間
# - 輸出範例：
#   ```
#   投資風險評估報告：
#
#   基本資料：
#     年齡：35 歲
#     年收入：1,200,000 元
#     投資經驗：5 年
#     風險承受度：中等
#
#   財務分析：
#     總資產：5,000,000 元
#     負債比例：30%
#     緊急準備金：600,000 元（年收入的 6 個月）
#     財務穩定度：穩定
#
#   投資建議：
#     基礎股票配置：65%（100 - 35）
#     風險承受度調整：0%（中等）
#     財務穩定度調整：+5%（穩定）
#     撫養責任調整：-10%（有撫養責任）
#     建議股票比例：60%
#     建議債券比例：40%
#
#   風險等級：中低風險
#   預期年化報酬：6-8%
#   ```
#
# **要求**：
# - 多層次的計算邏輯
# - 複雜的條件調整機制
# - 邊界值檢查與限制

# %%
# 在此撰寫你的程式碼

# %% [markdown]
# ---## 🎯 作業總結### 完成檢核清單- [ ] Part I：基礎題（習題 1-6）🟢- [ ] Part II：中階題（習題 7-12）🟡- [ ] Part III：進階題（習題 13-18）🔴- [ ] Part IV：挑戰題（習題 19-20）🟣### 自我評估完成作業後，請記錄：1. **完成時間**：_____ 分鐘2. **困難題目**：哪幾題花最多時間？3. **新學技巧**：有哪些意外的收穫？4. **待加強處**：哪些概念還需要複習？### 核心技能檢核完成本作業後，你應該能夠：- ✅ 熟練使用 if、elif、else 語句- ✅ 正確組合比較運算子和邏輯運算子- ✅ 設計複雜的條件判斷邏輯- ✅ 處理巢狀條件和多重條件- ✅ 實作實際生活中的決策系統- ✅ 除錯和優化條件判斷程式碼---## 📝 下一步完成詳解範例後，繼續進行 `03-practice.ipynb` 和 `04-exercises.ipynb`。- 基礎題：30-45 分鐘- 中階題：45-60 分鐘- 進階題：60-90 分鐘- 挑戰題：30-45 分鐘- **總計**：165-240 分鐘（2.5-4 小時）---## 💡 學習建議**加油！掌握條件判斷，你就具備了程式邏輯思維的基礎！** 💪
