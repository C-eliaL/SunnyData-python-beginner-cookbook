# %% [markdown]
# # Chapter 04: 課堂練習 | In-Class Practice
#
# ---
#
# ## 📋 練習說明
#
# 本檔案包含 **15 題**課堂練習，主題涵蓋：
# - if 單一條件判斷
# - if-else 二選一邏輯
# - if-elif-else 多選一邏輯
# - 比較運算子與邏輯運算子
# - 巢狀條件判斷
# - 三元運算子
#
# **建議完成時間**：45-60 分鐘
#
# **練習方式**：
# 1. 閱讀題目要求
# 2. 在程式碼格子中撰寫程式
# 3. 執行驗證結果
# 4. 對照範例輸出檢查正確性
#
# ---

# %% [markdown]
# ## 練習 1：成年判斷
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 請寫一個程式，輸入年齡，判斷是否已成年（18 歲以上）。如果已成年，顯示「已成年」。
#
# **範例**：
# ```
# 輸入：age = 20
# 輸出：已成年
#
# 輸入：age = 15
# 輸出：（無輸出）
# ```

# %%
# 在此撰寫你的程式碼
age = 20

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 2：奇偶數判斷
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 請寫一個程式，輸入一個整數，判斷是奇數還是偶數。
#
# **提示**：使用 `%` 運算子判斷餘數。
#
# **範例**：
# ```
# 輸入：number = 8
# 輸出：8 是偶數
#
# 輸入：number = 7
# 輸出：7 是奇數
# ```

# %%
# 在此撰寫你的程式碼
number = 8

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 3：正負數判斷
#
# **難度**：⭐ 基礎
#
# **題目描述**：
# 請寫一個程式，輸入一個數字，判斷是正數、負數還是零。
#
# **範例**：
# ```
# 輸入：num = 5
# 輸出：正數
#
# 輸入：num = -3
# 輸出：負數
#
# 輸入：num = 0
# 輸出：零
# ```

# %%
# 在此撰寫你的程式碼
num = 5

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 4：成績等級
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，根據分數判斷等級：
# - 90 分以上：A
# - 80-89 分：B
# - 70-79 分：C
# - 60-69 分：D
# - 60 分以下：F
#
# **範例**：
# ```
# 輸入：score = 85
# 輸出：等級：B
#
# 輸入：score = 92
# 輸出：等級：A
# ```

# %%
# 在此撰寫你的程式碼
score = 85

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 5：閏年判斷
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，判斷某年是否為閏年。
#
# **閏年規則**：
# - 能被 4 整除，但不能被 100 整除
# - 或者能被 400 整除
#
# **範例**：
# ```
# 輸入：year = 2024
# 輸出：2024 是閏年
#
# 輸入：year = 1900
# 輸出：1900 不是閏年
#
# 輸入：year = 2000
# 輸出：2000 是閏年
# ```

# %%
# 在此撰寫你的程式碼
year = 2024

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 6：BMI 計算與判斷
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，計算 BMI 並判斷健康狀況。
#
# **公式**：BMI = 體重(kg) / 身高(m)²
#
# **分類**：
# - BMI < 18.5：過輕
# - 18.5 ≤ BMI < 24：正常
# - 24 ≤ BMI < 27：過重
# - BMI ≥ 27：肥胖
#
# **範例**：
# ```
# 輸入：weight = 70, height = 1.75
# 輸出：
# BMI: 22.86
# 健康狀況: 正常
# ```

# %%
# 在此撰寫你的程式碼
weight = 70
height = 1.75

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 7：三個數字找最大值
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，輸入三個數字，找出最大值。
#
# **提示**：使用巢狀條件或多個條件判斷。
#
# **範例**：
# ```
# 輸入：a = 5, b = 12, c = 8
# 輸出：最大值是 12
# ```

# %%
# 在此撰寫你的程式碼
a = 5
b = 12
c = 8

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 8：登入驗證
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，驗證使用者名稱和密碼。
#
# **要求**：
# - 正確的使用者名稱："admin"
# - 正確的密碼："python123"
# - 兩者都正確才顯示「登入成功」
# - 否則顯示「帳號或密碼錯誤」
#
# **範例**：
# ```
# 輸入：username = "admin", password = "python123"
# 輸出：登入成功
#
# 輸入：username = "admin", password = "wrong"
# 輸出：帳號或密碼錯誤
# ```

# %%
# 在此撰寫你的程式碼
username = "admin"
password = "python123"

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 9：購物折扣計算
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請寫一個程式，計算購物折扣。
#
# **折扣規則**：
# - 消費滿 5000 元：9 折
# - 消費滿 3000 元：95 折
# - 消費未滿 3000 元：無折扣
# - 如果是 VIP 會員，額外再打 9 折
#
# **範例**：
# ```
# 輸入：amount = 6000, is_vip = True
# 輸出：
# 原價：6000 元
# 折扣後：4860 元 (9折 × VIP再9折)
#
# 輸入：amount = 2500, is_vip = False
# 輸出：
# 原價：2500 元
# 折扣後：2500 元 (無折扣)
# ```

# %%
# 在此撰寫你的程式碼
amount = 6000
is_vip = True

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 10：季節判斷
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請寫一個程式，根據月份判斷季節（台灣）。
#
# **季節劃分**：
# - 春季：3, 4, 5 月
# - 夏季：6, 7, 8 月
# - 秋季：9, 10, 11 月
# - 冬季：12, 1, 2 月
#
# **範例**：
# ```
# 輸入：month = 7
# 輸出：夏季
#
# 輸入：month = 12
# 輸出：冬季
# ```

# %%
# 在此撰寫你的程式碼
month = 7

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 11：三角形判斷
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請寫一個程式，判斷三個邊長能否構成三角形，若可以，判斷是何種三角形。
#
# **判斷規則**：
# 1. 三角形成立條件：任兩邊之和大於第三邊
# 2. 等邊三角形：三邊相等
# 3. 等腰三角形：兩邊相等
# 4. 直角三角形：a² + b² = c²（畢氏定理）
# 5. 一般三角形：其他
#
# **範例**：
# ```
# 輸入：a = 3, b = 4, c = 5
# 輸出：可構成三角形 - 直角三角形
#
# 輸入：a = 5, b = 5, c = 5
# 輸出：可構成三角形 - 等邊三角形
#
# 輸入：a = 1, b = 2, c = 10
# 輸出：無法構成三角形
# ```

# %%
# 在此撰寫你的程式碼
a = 3
b = 4
c = 5

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 12：電費計算
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請寫一個程式，計算電費（累進費率）。
#
# **費率表**（每度單價）：
# - 120 度以下：2.5 元
# - 121-330 度：3.5 元
# - 331-500 度：4.5 元
# - 500 度以上：5.5 元
#
# **範例**：
# ```
# 輸入：usage = 250
# 輸出：
# 用電量：250 度
# 電費：755 元
# 計算：120×2.5 + 130×3.5 = 300 + 455 = 755
# ```

# %%
# 在此撰寫你的程式碼
usage = 250

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 13：使用三元運算子
#
# **難度**：⭐⭐ 中等
#
# **題目描述**：
# 請使用三元運算子改寫以下程式碼。
#
# **原始程式碼**：
# ```python
# score = 75
# if score >= 60:
#     result = "及格"
# else:
#     result = "不及格"
# print(result)
# ```
#
# **要求**：改用一行三元運算子完成。

# %%
# 在此撰寫你的程式碼
score = 75

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 14：密碼強度檢查
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請寫一個程式，檢查密碼強度。
#
# **強度判斷**：
# - 弱：長度小於 6
# - 中：長度 6-10 且包含數字
# - 強：長度大於 10 且同時包含數字和字母
#
# **提示**：
# - 使用 `len()` 檢查長度
# - 使用 `any(c.isdigit() for c in password)` 檢查是否包含數字
# - 使用 `any(c.isalpha() for c in password)` 檢查是否包含字母
#
# **範例**：
# ```
# 輸入：password = "abc"
# 輸出：密碼強度：弱
#
# 輸入：password = "abc123"
# 輸出：密碼強度：中
#
# 輸入：password = "MyPassword123"
# 輸出：密碼強度：強
# ```

# %%
# 在此撰寫你的程式碼
password = "abc123"

# %% [markdown]
# ---

# %% [markdown]
# ## 練習 15：綜合應用 - 學生獎學金判定
#
# **難度**：⭐⭐⭐ 進階
#
# **題目描述**：
# 請寫一個程式，判斷學生是否符合獎學金資格。
#
# **獎學金條件**（需同時滿足）：
# - 學業成績 >= 80 分
# - 操行成績 >= 85 分
# - 出席率 >= 90%
# - 無記過紀錄（has_demerit = False）
#
# **獎學金等級**：
# - 特優獎學金（20000 元）：學業 >= 90, 操行 >= 90, 出席率 >= 95%
# - 優等獎學金（10000 元）：學業 >= 85, 操行 >= 85, 出席率 >= 90%
# - 一般獎學金（5000 元）：學業 >= 80, 操行 >= 85, 出席率 >= 90%
# - 不符合資格：0 元
#
# **範例**：
# ```
# 輸入：
# academic = 92, conduct = 90, attendance = 0.96, has_demerit = False
#
# 輸出：
# === 獎學金評定結果 ===
# 學業成績：92
# 操行成績：90
# 出席率：96%
# 記過紀錄：無
# ---------------------
# 符合資格：特優獎學金
# 獎學金金額：20000 元
# ```

# %%
# 在此撰寫你的程式碼
academic = 92  # 學業成績
conduct = 90  # 操行成績
attendance = 0.96  # 出席率（0.96 = 96%）
has_demerit = False  # 是否有記過

# %% [markdown]
# ---
#
# ## 🎉 練習完成！
#
# 完成所有練習後，請：
# 1. 檢查輸出是否符合範例
# 2. 嘗試修改變數值，測試不同情況
# 3. 理解每個條件判斷的邏輯
# 4. 繼續挑戰 `04-exercises.ipynb` 課後習題
#
# ---
