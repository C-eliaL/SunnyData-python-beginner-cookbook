# %% [markdown]
# # Chapter 4: 條件判斷 - 自我測驗
#
# ---
#
# ## 測驗說明
#
# **題目數量**：28 題
# **建議時間**：25 分鐘
# **及格分數**：21/28 (75%)
#
# **題型分布**：
# - 選擇題（單選）：15 題
# - 是非題：5 題
# - 程式輸出預測：5 題
# - 程式填空：3 題
#
# **作答方式**：
# 1. 選擇題：在心中選出答案或寫在紙上
# 2. 程式輸出題：預測程式執行結果
# 3. 程式填空題：在程式碼中填入正確內容
# 4. 作答完畢後，對照最後的解答區
#
# ---

# %% [markdown]
# ## Part I: 選擇題（Single Choice）
#
# 每題 1 分，共 15 分

# %% [markdown]
# ### 第 1 題
#
# 以下哪個是正確的 `if` 語法？
#
# A. `if x == 10`
# B. `if x == 10:`
# C. `if (x == 10)`
# D. `if x = 10:`

# %% [markdown]
# ### 第 2 題
#
# Python 使用什麼來定義程式碼區塊？
#
# A. 大括號 `{}`
# B. 縮排（Indentation）
# C. 分號 `;`
# D. begin/end 關鍵字

# %% [markdown]
# ### 第 3 題
#
# 標準的 Python 縮排應該使用幾個空格？
#
# A. 2 個空格
# B. 3 個空格
# C. 4 個空格
# D. 8 個空格

# %% [markdown]
# ### 第 4 題
#
# `if-elif-else` 結構中，哪個部分是可選的？
#
# A. `if`
# B. `elif`
# C. `else`
# D. B 和 C 都是可選的

# %% [markdown]
# ### 第 5 題
#
# 以下程式碼會輸出什麼？
#
# ```python
# x = 10
# if x > 5:
#     print("A")
# elif x > 8:
#     print("B")
# else:
#     print("C")
# ```
#
# A. `A`
# B. `B`
# C. `C`
# D. `A` 和 `B`

# %% [markdown]
# ### 第 6 題
#
# `and` 運算子在什麼情況下返回 `True`？
#
# A. 至少一個條件為 True
# B. 兩個條件都為 True
# C. 兩個條件都為 False
# D. 至少一個條件為 False

# %% [markdown]
# ### 第 7 題
#
# `or` 運算子在什麼情況下返回 `False`？
#
# A. 至少一個條件為 True
# B. 兩個條件都為 True
# C. 兩個條件都為 False
# D. 至少一個條件為 False

# %% [markdown]
# ### 第 8 題
#
# `not True` 的結果是什麼？
#
# A. `True`
# B. `False`
# C. `None`
# D. 錯誤

# %% [markdown]
# ### 第 9 題
#
# 以下哪個表達式等同於 `10 < x < 20`？
#
# A. `x > 10 and x < 20`
# B. `x >= 10 and x <= 20`
# C. `10 < x and x < 20`
# D. `x > 10 or x < 20`

# %% [markdown]
# ### 第 10 題
#
# 三元運算子的語法格式是什麼？
#
# A. `if 條件 then 值1 else 值2`
# B. `值1 if 條件 else 值2`
# C. `條件 ? 值1 : 值2`
# D. `值1 when 條件 else 值2`

# %% [markdown]
# ### 第 11 題
#
# 以下程式碼的問題是什麼？
#
# ```python
# age = 20
# if age = 18:
#     print("成年")
# ```
#
# A. 縮排錯誤
# B. 應該用 `==` 而不是 `=`
# C. 缺少冒號
# D. 沒有問題

# %% [markdown]
# ### 第 12 題
#
# 以下哪個條件判斷最有效率？
#
# ```python
# # A
# if score >= 90:
#     grade = "A"
# elif score >= 80:
#     grade = "B"
#
# # B
# if score >= 60:
#     grade = "D"
# elif score >= 80:
#     grade = "B"
# ```
#
# A. A（從大到小）
# B. B（從小到大）
# C. 效率相同
# D. 兩者都錯誤

# %% [markdown]
# ### 第 13 題
#
# 巢狀條件是什麼意思？
#
# A. 條件判斷內包含另一個條件判斷
# B. 使用多個 `elif`
# C. 使用 `and` 或 `or`
# D. 條件判斷在迴圈內

# %% [markdown]
# ### 第 14 題
#
# 短路求值（Short-circuit Evaluation）是什麼意思？
#
# A. 縮短程式碼長度
# B. 當邏輯運算子的結果已確定時，不再評估後續表達式
# C. 使用三元運算子
# D. 減少縮排層級

# %% [markdown]
# ### 第 15 題
#
# 以下哪個不是 Python 的比較運算子？
#
# A. `==`
# B. `!=`
# C. `<>`
# D. `<=`

# %% [markdown]
# ---
#
# ## Part II: 是非題（True/False）
#
# 每題 1 分，共 5 分

# %% [markdown]
# ### 第 16 題
#
# 在 `if-elif-else` 結構中，可以同時執行多個分支。
#
# A. True
# B. False

# %% [markdown]
# ### 第 17 題
#
# Python 的縮排可以混用空格和 Tab。
#
# A. True
# B. False

# %% [markdown]
# ### 第 18 題
#
# `elif` 可以單獨使用，不需要 `if`。
#
# A. True
# B. False

# %% [markdown]
# ### 第 19 題
#
# 條件表達式的結果必須是布林值（True 或 False）。
#
# A. True
# B. False

# %% [markdown]
# ### 第 20 題
#
# 三元運算子適合處理複雜的多重條件判斷。
#
# A. True
# B. False

# %% [markdown]
# ---
#
# ## Part III: 程式輸出預測（Code Output Prediction）
#
# 每題 2 分，共 10 分
#
# **說明**：請預測以下程式碼的輸出結果

# %% [markdown]
# ### 第 21 題
#
# ```python
# x = 15
# if x > 10:
#     print("A")
# if x > 20:
#     print("B")
# print("C")
# ```
#
# 輸出：
# ```
# _____________________
# _____________________
# ```

# %% [markdown]
# ### 第 22 題
#
# ```python
# score = 85
# if score >= 90:
#     result = "優秀"
# elif score >= 80:
#     result = "良好"
# elif score >= 70:
#     result = "中等"
# print(result)
# ```
#
# 輸出：
# ```
# _____________________
# ```

# %% [markdown]
# ### 第 23 題
#
# ```python
# a = 5
# b = 10
# if a > 3 and b > 15:
#     print("True")
# else:
#     print("False")
# ```
#
# 輸出：
# ```
# _____________________
# ```

# %% [markdown]
# ### 第 24 題
#
# ```python
# age = 16
# status = "成年" if age >= 18 else "未成年"
# print(status)
# ```
#
# 輸出：
# ```
# _____________________
# ```

# %% [markdown]
# ### 第 25 題
#
# ```python
# x = 10
# if x > 5:
#     if x < 15:
#         print("範圍內")
#     else:
#         print("太大")
# else:
#     print("太小")
# ```
#
# 輸出：
# ```
# _____________________
# ```

# %% [markdown]
# ---
#
# ## Part IV: 程式填空（Code Completion）
#
# 每題 2 分，共 6 分
#
# **說明**：在空白處填入正確的程式碼

# %% [markdown]
# ### 第 26 題
#
# 完成以下程式，判斷一個數字是正數、負數還是零：
#
# ```python
# num = -5
# if ____________:
#     print("正數")
# elif ____________:
#     print("負數")
# else:
#     print("零")
# ```

# %% [markdown]
# ### 第 27 題
#
# 完成以下程式，判斷一個年份是否為閏年（能被 4 整除但不能被 100 整除，或能被 400 整除）：
#
# ```python
# year = 2024
# if (year % 4 == 0 _______ year % 100 != 0) _______ year % 400 == 0:
#     print("閏年")
# else:
#     print("平年")
# ```

# %% [markdown]
# ### 第 28 題
#
# 使用三元運算子完成以下程式，判斷奇偶數：
#
# ```python
# num = 7
# result = ____________ if ____________ else ____________
# print(result)
# ```
#
# 要求：輸出 "奇數" 或 "偶數"

# %% [markdown]
# ---
#
# ## 解答區
#
# **請在作答完畢後再查看解答**
#
# ---

# %% [markdown]
# ### Part I: 選擇題解答
#
# | 題號 | 答案 | 說明 |
# |:-----|:-----|:-----|
# | 1 | B | `if` 語句必須以冒號 `:` 結尾 |
# | 2 | B | Python 使用縮排定義程式碼區塊 |
# | 3 | C | PEP 8 規範建議使用 4 個空格 |
# | 4 | D | `elif` 和 `else` 都是可選的，只有 `if` 是必須的 |
# | 5 | A | 第一個條件 `x > 5` 為真，輸出 "A"，後續不再檢查 |
# | 6 | B | `and` 運算子要求兩個條件都為 True |
# | 7 | C | `or` 運算子只有在兩個條件都為 False 時才返回 False |
# | 8 | B | `not` 運算子反轉布林值，`not True` 為 `False` |
# | 9 | C | `10 < x < 20` 等同於 `10 < x and x < 20` |
# | 10 | B | Python 的三元運算子格式是 `值1 if 條件 else 值2` |
# | 11 | B | 比較應該用 `==`，`=` 是賦值運算子 |
# | 12 | A | 從大到小判斷更符合邏輯，B 的順序會導致錯誤結果 |
# | 13 | A | 巢狀條件是指條件判斷內包含另一個條件判斷 |
# | 14 | B | 短路求值是指當結果已確定時，不再評估後續表達式 |
# | 15 | C | `<>` 不是 Python 的比較運算子（是舊版 Python 2 語法） |

# %% [markdown]
# ### Part II: 是非題解答
#
# | 題號 | 答案 | 說明 |
# |:-----|:-----|:-----|
# | 16 | B (False) | `if-elif-else` 只會執行第一個為真的分支 |
# | 17 | B (False) | 不能混用空格和 Tab，會導致錯誤 |
# | 18 | B (False) | `elif` 必須跟在 `if` 或另一個 `elif` 之後 |
# | 19 | A (True) | 條件表達式的結果必須能轉換為布林值 |
# | 20 | B (False) | 三元運算子只適合簡單的二選一邏輯 |

# %% [markdown]
# ### Part III: 程式輸出預測解答
#
# #### 第 21 題
# ```
# A
# C
# ```
# **說明**：第一個 `if` 為真（15 > 10），輸出 "A"；第二個 `if` 為假（15 不大於 20），跳過；最後無條件輸出 "C"

# %%
# 驗證第 21 題
x = 15
if x > 10:
    print("A")
if x > 20:
    print("B")
print("C")

# %% [markdown]
# #### 第 22 題
# ```
# 良好
# ```
# **說明**：85 不滿足第一個條件（>= 90），但滿足第二個條件（>= 80），輸出 "良好"

# %%
# 驗證第 22 題
score = 85
if score >= 90:
    result = "優秀"
elif score >= 80:
    result = "良好"
elif score >= 70:
    result = "中等"
print(result)

# %% [markdown]
# #### 第 23 題
# ```
# False
# ```
# **說明**：`a > 3` 為真（5 > 3），但 `b > 15` 為假（10 不大於 15），`and` 運算結果為假

# %%
# 驗證第 23 題
a = 5
b = 10
if a > 3 and b > 15:
    print("True")
else:
    print("False")

# %% [markdown]
# #### 第 24 題
# ```
# 未成年
# ```
# **說明**：age（16）不滿足 >= 18，執行 `else` 部分，返回 "未成年"

# %%
# 驗證第 24 題
age = 16
status = "成年" if age >= 18 else "未成年"
print(status)

# %% [markdown]
# #### 第 25 題
# ```
# 範圍內
# ```
# **說明**：`x > 5` 為真（10 > 5），進入外層 if；`x < 15` 也為真（10 < 15），輸出 "範圍內"

# %%
# 驗證第 25 題
x = 10
if x > 5:
    if x < 15:
        print("範圍內")
    else:
        print("太大")
else:
    print("太小")

# %% [markdown]
# ### Part IV: 程式填空解答
#
# #### 第 26 題
# ```python
# num = -5
# if num > 0:
#     print("正數")
# elif num < 0:
#     print("負數")
# else:
#     print("零")
# ```

# %%
# 驗證第 26 題
num = -5
if num > 0:
    print("正數")
elif num < 0:
    print("負數")
else:
    print("零")

# %% [markdown]
# #### 第 27 題
# ```python
# year = 2024
# if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
#     print("閏年")
# else:
#     print("平年")
# ```
#
# **說明**：閏年條件是「能被 4 整除且不能被 100 整除」或「能被 400 整除」

# %%
# 驗證第 27 題
year = 2024
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("閏年")
else:
    print("平年")

# %% [markdown]
# #### 第 28 題
# ```python
# num = 7
# result = "奇數" if num % 2 == 1 else "偶數"
# print(result)
# ```
#
# **另一種寫法**（判斷餘數不為 0）：
# ```python
# result = "奇數" if num % 2 != 0 else "偶數"
# ```

# %%
# 驗證第 28 題
num = 7
result = "奇數" if num % 2 == 1 else "偶數"
print(result)

# %% [markdown]
# ---
#
# ## 計分與評估
#
# ### 計分標準
# - Part I (選擇題)：15 題 × 1 分 = 15 分
# - Part II (是非題)：5 題 × 1 分 = 5 分
# - Part III (程式輸出)：5 題 × 2 分 = 10 分（每題完全正確才給分）
# - Part IV (程式填空)：3 題 × 2 分 = 6 分（每題完全正確才給分）
# - **總分**：36 分（調整為 28 分滿分制，建議按比例換算）
#
# ### 等級劃分（以 28 分為基準）
# - **優秀** (90%+)：25-28 分
# - **良好** (80-89%)：22-24 分
# - **及格** (75-79%)：21 分
# - **待加強** (<75%)：< 21 分
#
# ### 換算方式
# 實際得分 ÷ 36 × 28 = 調整後分數
#
# ---

# %% [markdown]
# ## 重點觀念總結
#
# 完成本測驗後，您應該掌握以下核心概念：
#
# ### 1. 條件判斷語法
# - ✅ `if` / `if-else` / `if-elif-else` 的正確語法
# - ✅ 冒號 `:` 和縮排的重要性
# - ✅ 條件表達式的布林值特性
#
# ### 2. 運算子
# - ✅ 比較運算子：`>`, `<`, `>=`, `<=`, `==`, `!=`
# - ✅ 邏輯運算子：`and`, `or`, `not`
# - ✅ 鏈式比較：`a < b < c`
#
# ### 3. 執行流程
# - ✅ `if-elif-else` 的短路特性（只執行第一個為真的分支）
# - ✅ 條件判斷的順序重要性
# - ✅ 巢狀條件的層級邏輯
#
# ### 4. 進階技巧
# - ✅ 三元運算子的使用時機
# - ✅ 短路求值的效能優化
# - ✅ 條件邏輯的簡化方法
#
# ### 5. 常見誤區
# - ⚠️ 混淆 `=` (賦值) 和 `==` (比較)
# - ⚠️ 縮排錯誤或不一致
# - ⚠️ 條件順序錯誤（如先判斷 >= 60 再判斷 >= 90）
# - ⚠️ 邏輯運算子使用錯誤
#
# ---

# %% [markdown]
# ## 下一步建議
#
# ### 如果分數 < 21 分（待加強）
# 1. 重新閱讀 `01-lecture.ipynb`
# 2. 仔細研究 `02-worked-examples.ipynb` 的詳解
# 3. 完成 `03-practice.ipynb` 課堂練習
# 4. 再次進行本測驗
#
# ### 如果分數 ≥ 21 分（及格以上）
# 1. 完成 `04-exercises.ipynb` 課後習題
# 2. 對照 `05-solutions.ipynb` 檢視解答
# 3. 進入 **Chapter 5: 迴圈基礎**
# 4. 挑戰 **Milestone 2: 猜數字遊戲**
#
# ---
#
# **恭喜完成 Chapter 4 測驗！繼續保持學習熱情！** 💪
